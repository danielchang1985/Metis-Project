# %%
from IPython.core.display import display, HTML
display(HTML(
    '<style>'
        '#notebook { padding-top:0px !important; } ' 
        '.container { width:100% !important; } '
        '.end_space { min-height:0px !important; } '
    '</style>'
))


from bs4 import BeautifulSoup
import requests
import re
import pandas as pd
# Out:
# <style>#notebook { padding-top:0px !important; } .container { width:100% !important; } .end_space { min-height:0px !important; } </style>

# %%
from IPython.core.display import display, HTML
#display(HTML(my_html))     # make sure Jupyter knows to display it as HTML

# %%
listings_name = []
listings_price = []

# %%
listings_address_district=[]
listings_remaining_info = []

listings_type = []
listings_ri2 = []

listings_age = []
listings_ri3 = []

listings_bednbath = []
listings_ri4 = []

listings_size = []

# %%
def NamePriceSeparator(listings_namenprice):
    for i in range(len(listings_namenprice)):
        if i%2 ==0:
            listings_name.append(listings_namenprice[i].text)
        else:
            listings_price.append(listings_namenprice[i].text)
    return

# %%
totalpages = 80
for i in range(1, totalpages + 1):
    i = str(i)
    url = 'https://www.99.co/singapore/sale/condos-apartments?page_num=' + i 
    response = requests.get(url)
    page = response.text
    soup = BeautifulSoup(page, "lxml")
    listings_namenprice = soup.find_all('h3', class_="Z0npN _1T6Ql")
    NamePriceSeparator (listings_namenprice)
    
    
    listings = soup.find_all('p', class_="JPolj TMSN-")   

    for i in range(len(listings)):
        if i%6 ==0:
            listings_address_district.append(listings[i].text)
        else:
            listings_remaining_info.append(listings[i].text)
            
    for i in range(len(listings_remaining_info)):
        if i%5 == 0:
            listings_type.append(listings_remaining_info[i])
        else:
            listings_ri2.append(listings_remaining_info[i])
            
    for i in range(len(listings_ri2)):
        if i%4 == 0:
            listings_age.append(listings_ri2[i])
        else:
            listings_ri3.append(listings_ri2[i])
            
    for i in range(len(listings_ri3)):
        if i%3 == 0:
            listings_bednbath.append(listings_ri3[i])
        else:
            listings_ri4.append(listings_ri3[i])

    for i in range(len(listings_ri4)):
        if i%2 != 0:
            listings_size.append(listings_ri4[i])
   
    listings_remaining_info = []
    listings_ri2 = []
    listings_ri3 = []
    listings_ri4 = []

# %%
listings_price[2800]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-66-5cae15dac210> in <module>
# ----> 1 listings_price[2800]
#
# IndexError: list index out of range

# %%
#Take out the '$' and ',' and convert to int.
for item in range(len(listings_price)):
    listings_price[item] = int(listings_price[item].replace('$', '').replace(',', ''))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-36-a7867a0b8c05> in <module>
#       1 #Take out the '$' and ',' and convert to int.
#       2 for item in range(len(listings_price)):
# ----> 3     listings_price[item] = int(listings_price[item].replace('$', '').replace(',', ''))
#
# ValueError: invalid literal for int() with base 10: 'To be confirmed'

# %%
#split the listings_address_district into address and District and put them in separate lists
listings_Address = []
listings_District = []
listings_address_district =([select for size in listings_address_district for select in size.split('·')])
for item in range(len(listings_address_district)):
    if (item % 2 == 0):
        listings_Address.append(listings_address_district[item])
    else:
        listings_District.append(listings_address_district[item])

# %%
#some bugger went to key in Floor #** instead of D*, so we replace them with a certain District D0
x = 'Floor'
for n, item in enumerate(listings_District):
    if x in item:
        listings_District[n] = ' D0'
        listings_District[n] = str(listings_District[n])

# %%
#split the listings_age into Completion Date(YYYY) and type of Leasehold and put them in separate lists
listings_CompletionYr = []
listings_Leasehold = []
listings_age =([select for size in listings_age for select in size.split('·')])
listings_age
for item in range(len(listings_age)):
    if (item % 2 == 0):
        listings_CompletionYr.append(listings_age[item])
    else:
        listings_Leasehold.append(listings_age[item])

# %%
for item in range(len(listings_bednbath)):
    if listings_bednbath[item] == '':
        listings_bednbath[item] = ('Na 0 ')

# %%
#split the listings_bednbath into respective categories and put them in separate lists
listings_bedroom =[]
listings_bathroom =[]

listings_bednbath = [select for room in listings_bednbath for select in room.split(' ')]
#After splitting, there is an empty '' in the order of consecutive 3rd element in the list, hence we drop the ''
listings_bednbath[:] = [item for item in listings_bednbath if item != '']

for item in range(len(listings_bednbath)):
    if (item % 2 == 0):
        listings_bedroom.append(listings_bednbath[item])
    else:
        listings_bathroom.append(listings_bednbath[item])

# %%
#convert listings_bathroom into int
for item in range(len(listings_bathroom)):
    listings_bathroom[item] = int(listings_bathroom[item])

# %%
#split the listings_size into sqft and sqm and put them in separate lists
listings_sqft = []
listings_sqm = []
listings_size =([select for size in listings_size for select in size.split('/')])

for item in range(len(listings_size)):
    if (item % 2 == 0):
        listings_sqft.append(listings_size[item])
    else:
        listings_sqm.append(listings_size[item])

# %%
#Remove ',' and ' sqft ' and convert to int
for item in range(len(listings_sqft)):
    listings_sqft[item] =int(listings_sqft[item].replace(',','').replace(' sqft ',''))

# %%
#Remove ' ' and ' sqm ' and convert to float
for item in range(len(listings_sqm)):
    listings_sqm[item] =float(listings_sqm[item].replace(',','').replace(' ','').replace('sqm',''))

# %%
#Now we combine all the lists into a dictionary
data = []
data = [{'Name': nam, 'Price': pri, 'Address': add, 'District': dis, 'Completion_Year':com, 'Leasehold':lea, 'Bedroom':bed, 'Bathroom':bath, 
         'Sqft':sqf, 'Sqm':sqm } for nam, pri, add, dis, com, lea, bed, bath, sqf, sqm in zip(listings_name, listings_price, listings_Address, 
         listings_District, listings_CompletionYr, listings_Leasehold, listings_bedroom, listings_bathroom, listings_sqft, listings_sqm)
       ]

# %%
data
# Out:
# [{'Name': 'Neptune Court',
#   'Price': 1650000,
#   'Address': '10 Marine Vista ',
#   'District': ' D15',
#   'Completion_Year': '1975 ',
#   'Leasehold': ' 99 years',
#   'Bedroom': '3',
#   'Bathroom': 2,
#   'Sqft': 1636,
#   'Sqm': 151.98},
#  {'Name': 'TRE Residences',
#   'Price': 1600000,
#   'Address': '9 Geylang East Avenue 1 ',
#   'District': ' D14',
#   'Completion_Year': '2019 ',
#   'Leasehold': ' 99 years',
#   'Bedroom': '4',
#   'Bathroom': 3,
#   'Sqft': 947,
#   'Sqm': 87.97},
#  {'Name': 'Citylights',
#   'Price': 1200000,
#   'Address': '86 Jellicoe Road ',
#   'District': ' D8',
#   'Completion_Year': '2007 ',
#   'Leasehold': ' 99 years',
#   'Bedroom': '1',
#   'Bathroom': 1,
#   'Sqft': 689,
#   'Sqm': 64.01},
#  {'Name': 'Spottiswoode Residences',
#   'Price': 1938000,
#   'Address': '48 Spottiswoode Park Road ',
#   'District': ' D2',
#   'Completion_Year': '2014 ',
#   'Leasehold': ' Freehold',
#   'Bedroom': '2',
#   'Bathroom': 2,
#   'Sqft': 926,
#   'Sqm': 86.02},
#  {'Name': 'J Gateway',
#   'Price': 1380000,
#   'Address': '2 Gateway Drive ',
#   'District': ' D22',
#   'Completion_Year': '2017 ',
#   'Leasehold': ' 99 years',
#   'Bedroom': '3',
#   'Bathroom': 3,
#   'Sqft': 893,
#   'Sqm': 82.96},
#  {'Name': '8 St Thomas',
#   'Price': 5961000,
#   'Address': '8 Saint Thomas Walk ',
#   'District': ' D9',
#   'Completion_Year': '2018 ',
#   'Leasehold': ' Freehold',
#   'Bedroom': '4',
#   'Bathroom': 3,
#   'Sqft': 1744,
#   'Sqm': 162.02},
#  {'Name': 'Sky Habitat',
#   'Price': 1220000,
#   'Address': '7 Bishan Street 15 ',
#   'District': ' D20',
#   'Completion_Year': '2015 ',
#   'Leasehold': ' 99 years',
#   'Bedroom': '1',
#   'Bathroom': 1,
#   'Sqft': 711,
#   'Sqm': 66.05},
#  {'Name': 'Euhabitat',
#   'Price': 720000,
#   'Address': '226 Jalan Eunos ',
#   'District': ' D14',
#   'Completion_Year': '2015 ',
#   'Leasehold': ' 99 years',
#   'Bedroom': '1',
#   'Bathroom': 1,
#   'Sqft': 527,
#   'Sqm': 48.95},
#  {'Name': 'Eastwood Regency',
#   'Price': 1300000,
#   'Address': '40 Eastwood Road ',
#   'District': ' D16',
#   'Completion_Year': '2013 ',
#   'Leasehold': ' Freehold',
#   'Bedroom': '2',
#   'Bathroom': 2,
#   'Sqft': 1119,
#   'Sqm': 103.95},
#  {'Name': 'Bellezza @ Katong',
#   'Price': 828000,
#   'Address': '46 Ceylon Road ',
#   'District': ' D15',
#   'Completion_Year': '2008 ',
#   'Leasehold': ' Freehold',
#   'Bedroom': '1',
#   'Bathroom': 1,
#   'Sqft': 603,
#   'Sqm': 56.02},
#  {'Name': 'Faber Crest',
#   'Price': 1220000,
#   'Address': '50K Faber Heights ',
#   'District': ' D5',
#   'Completion_Year': '2001 ',
#   'Leasehold': ' 99 years',
#   'Bedroom': '3',
#   'Bathroom': 3,
#   'Sqft': 1259,
#   'Sqm': 116.96},
#  {'Name': 'The Crest',
#   'Price': 3405880,
#   'Address': '103 Prince Charles Crescent ',
#   'District': ' D3',
#   'Completion_Year': '2018 ',
#   'Leasehold': ' 99 years',
#   'Bedroom': '4',
#   'Bathroom': 4,
#   'Sqft': 1625,
#   'Sqm': 150.96},
#  {'Name': 'The Sail @ Marina Bay',
#   'Price': 1398888,
#   'Address': '6 Marina Boulevard ',
#   'District': ' D1',
#   'Completion_Year': '2008 ',
#   'Leasehold': ' 99 years',
#   'Bedroom': '1',
#   'Bathroom': 1,
#   'Sqft': 689,
#   'Sqm': 64.01},
#  {'Name': 'Suites De Laurel',
#   'Price': 1000000,
#   'Address': '2 Jalan Anak Bukit ',
#   'District': ' D21',
#   'Completion_Year': '2012 ',
#   'Leasehold': ' 999 years',
#   'Bedroom': '1',
#   'Bathroom': 1,
#   'Sqft': 624,
#   'Sqm': 57.97},
#  {'Name': 'The Aston',
#   'Price': 1100000,
#   'Address': '2 Kay Poh Road ',
#   'District': ' D10',
#   'Completion_Year': '2002 ',
#   'Leasehold': ' Freehold',
#   'Bedroom': '1',
#   'Bathroom': 1,
#   'Sqft': 646,
#   'Sqm': 60.01},
#  {'Name': 'Queens Peak',
#   'Price': 1658800,
#   'Address': '3 Dundee Road ',
#   'District': ' D3',
#   'Completion_Year': '2020 ',
#   'Leasehold': ' 99 years',
#   'Bedroom': '3',
#   'Bathroom': 2,
#   'Sqft': 850,
#   'Sqm': 78.96},
#  {'Name': 'Esparina Residences',
#   'Price': 1150000,
#   'Address': '125 Compassvale Bow ',
#   'District': ' D19',
#   'Completion_Year': '2013 ',
#   'Leasehold': ' 99 years',
#   'Bedroom': '2',
#   'Bathroom': 2,
#   'Sqft': 935,
#   'Sqm': 86.86},
#  {'Name': 'The Trilinq',
#   'Price': 1560000,
#   'Address': '28 Jalan Lempeng ',
#   'District': ' D5',
#   'Completion_Year': '2017 ',
#   'Leasehold': ' 99 years',
#   'Bedroom': '3',
#   'Bathroom': 2,
#   'Sqft': 915,
#   'Sqm': 85.0},
#  {'Name': 'The Petals',
#   'Price': 1250000,
#   'Address': '89 Hillview Avenue ',
#   'District': ' D23',
#   'Completion_Year': '2002 ',
#   'Leasehold': ' Freehold',
#   'Bedroom': '2',
#   'Bathroom': 3,
#   'Sqft': 1076,
#   'Sqm': 99.96},
#  {'Name': 'Vacanza @ East',
#   'Price': 1330000,
#   'Address': '38 Lengkong Tujoh ',
#   'District': ' D14',
#   'Completion_Year': '2014 ',
#   'Leasehold': ' Freehold',
#   'Bedroom': '3',
#   'Bathroom': 2,
#   'Sqft': 1033,
#   'Sqm': 95.96},
#  {'Name': 'Trilive',
#   'Price': 999000,
#   'Address': '111 Tampines Road ',
#   'District': ' D19',
#   'Completion_Year': '2018 ',
#   'Leasehold': ' Freehold',
#   'Bedroom': '2',
#   'Bathroom': 2,
#   'Sqft': 624,
#   'Sqm': 57.97},
#  {'Name': 'Grand Residence',
#   'Price': 1138000,
#   'Address': '54 Lorong G Telok Kurau ',
#   'District': ' D15',
#   'Completion_Year': '2008 ',
#   'Leasehold': ' Freehold',
#   'Bedroom': '2',
#   'Bathroom': 2,
#   'Sqft': 915,
#   'Sqm': 85.0},
#  {'Name': 'Jade Residences',
#   'Price': 1360000,
#   'Address': '1 Lew Lian Vale ',
#   'District': ' D19',
#   'Completion_Year': '2017 ',
#   'Leasehold': ' Freehold',
#   'Bedroom': '2',
#   'Bathroom': 1,
#   'Sqft': 1012,
#   'Sqm': 94.01},
#  {'Name': 'The Montage',
#   'Price': 2100000,
#   'Address': '50 Lorong M Telok Kurau ',
#   'District': ' D15',
#   'Completion_Year': '2010 ',
#   'Leasehold': ' Freehold',
#   'Bedroom': '3',
#   'Bathroom': 3,
#   'Sqft': 1819,
#   'Sqm': 168.99},
#  {'Name': 'Mount Sophia Suites',
#   'Price': 950000,
#   'Address': '95 Sophia Road ',
#   'District': ' D9',
#   'Completion_Year': '2010 ',
#   'Leasehold': ' Freehold',
#   'Bedroom': '1',
#   'Bathroom': 1,
#   'Sqft': 560,
#   'Sqm': 52.02},
#  {'Name': 'Vibes @ East Coast',
#   'Price': 630000,
#   'Address': '308 Telok Kurau Road ',
#   'District': ' D15',
#   'Completion_Year': '2015 ',
#   'Leasehold': ' Freehold',
#   'Bedroom': '1',
#   'Bathroom': 1,
#   'Sqft': 409,
#   'Sqm': 37.99},
#  {'Name': 'Kerrisdale',
#   'Price': 1699000,
#   'Address': '30 Sturdee Road ',
#   'District': ' D8',
#   'Completion_Year': '2005 ',
#   'Leasehold': ' 99 years',
#   'Bedroom': '4',
#   'Bathroom': 4,
#   'Sqft': 1485,
#   'Sqm': 137.96},
#  {'Name': 'Viz @ Holland',
#   'Price': 1600000,
#   'Address': '221 Queensway ',
#   'District': ' D10',
#   'Completion_Year': '2008 ',
#   'Leasehold': ' Freehold',
#   'Bedroom': '2',
#   'Bathroom': 2,
#   'Sqft': 947,
#   'Sqm': 87.97},
#  {'Name': 'Nim Gardens',
#   'Price': 1700000,
#   'Address': '75 Nim Road ',
#   'District': ' D28',
#   'Completion_Year': '1986 ',
#   'Leasehold': ' Freehold',
#   'Bedroom': '3',
#   'Bathroom': 4,
#   'Sqft': 1830,
#   'Sqm': 170.01},
#  {'Name': 'Natura @ Hillview',
#   'Price': 1420000,
#   'Address': '22 Hillview Terrace ',
#   'District': ' D23',
#   'Completion_Year': '2015 ',
#   'Leasehold': ' Freehold',
#   'Bedroom': '3',
#   'Bathroom': 2,
#   'Sqft': 1216,
#   'Sqm': 112.97},
#  {'Name': 'The Jade',
#   'Price': 1099999,
#   'Address': '9 Bukit Batok Central Link ',
#   'District': ' D23',
#   'Completion_Year': '2004 ',
#   'Leasehold': ' 99 years',
#   'Bedroom': '2',
#   'Bathroom': 2,
#   'Sqft': 1012,
#   'Sqm': 94.01},
#  {'Name': 'Roots @ Transit',
#   'Price': 639000,
#   'Address': '9 Transit Road ',
#   'District': ' D26',
#   'Completion_Year': '2023 ',
#   'Leasehold': ' 99 years',
#   'Bedroom': '1',
#   'Bathroom': 1,
#   'Sqft': 520,
#   'Sqm': 48.3},
#  {'Name': 'The Quayside',
#   'Price': 1690000,
#   'Address': '60 Robertson Quay ',
#   'District': ' D9',
#   'Completion_Year': '1998 ',
#   'Leasehold': ' 99 years',
#   'Bedroom': '2',
#   'Bathroom': 2,
#   'Sqft': 1130,
#   'Sqm': 104.98},
#  {'Name': 'The Rise @ Oxley',
#   'Price': 1499000,
#   'Address': '73 Oxley Rise ',
#   'District': ' D9',
#   'Completion_Year': '2018 ',
#   'Leasehold': ' Freehold',
#   'Bedroom': '3',
#   'Bathroom': 2,
#   'Sqft': 668,
#   'Sqm': 62.05},
#  {'Name': 'J Gateway',
#   'Price': 880000,
#   'Address': '6 Gateway Drive ',
#   'District': ' D22',
#   'Completion_Year': '2017 ',
#   'Leasehold': ' 99 years',
#   'Bedroom': '1',
#   'Bathroom': 1,
#   'Sqft': 474,
#   'Sqm': 44.03},
#  {'Name': 'Euphony Gardens',
#   'Price': 748000,
#   'Address': '5 Jalan Mata Ayer ',
#   'District': ' D27',
#   'Completion_Year': '2001 ',
#   'Leasehold': ' 99 years',
#   'Bedroom': '2',
#   'Bathroom': 3,
#   'Sqft': 1206,
#   'Sqm': 112.04},
#  {'Name': 'Suites @ Guillemard',
#   'Price': 1288888,
#   'Address': '70 Lim Ah Woo Road ',
#   'District': ' D15',
#   'Completion_Year': '2014 ',
#   'Leasehold': ' Freehold',
#   'Bedroom': '2',
#   'Bathroom': 2,
#   'Sqft': 1033,
#   'Sqm': 95.96},
#  {'Name': 'Palm Oasis',
#   'Price': 1045000,
#   'Address': '51 Lorong H Telok Kurau ',
#   'District': ' D15',
#   'Completion_Year': '2009 ',
#   'Leasehold': ' Freehold',
#   'Bedroom': '2',
#   'Bathroom': 2,
#   'Sqft': 743,
#   'Sqm': 69.02},
#  {'Name': 'Tiong Bahru Estate',
#   'Price': 720000,
#   'Address': '56 Eng Hoon Street ',
#   'District': ' D3',
#   'Completion_Year': ' ',
#   'Leasehold': ' 99 years',
#   'Bedroom': '2',
#   'Bathroom': 1,
#   'Sqft': 720,
#   'Sqm': 66.89},
#  {'Name': 'The Tembusu',
#   'Price': 2588000,
#   'Address': '107 Tampines Road ',
#   'District': ' D19',
#   'Completion_Year': '2017 ',
#   'Leasehold': ' Freehold',
#   'Bedroom': '3',
#   'Bathroom': 3,
#   'Sqft': 1389,
#   'Sqm': 129.04},
#  {'Name': 'Rivertrees Residences',
#   'Price': 970000,
#   'Address': '29 Fernvale Close ',
#   'District': ' D28',
#   'Completion_Year': '2018 ',
#   'Leasehold': ' 99 years',
#   'Bedroom': '2',
#   'Bathroom': 2,
#   'Sqft': 710,
#   'Sqm': 65.96},
#  {'Name': 'Euhabitat',
#   'Price': 710000,
#   'Address': '210 Jalan Eunos ',
#   'District': ' D14',
#   'Completion_Year': '2015 ',
#   'Leasehold': ' 99 years',
#   'Bedroom': '1',
#   'Bathroom': 1,
#   'Sqft': 624,
#   'Sqm': 57.97},
#  {'Name': 'Northoaks',
#   'Price': 847000,
#   'Address': '28 Woodlands Crescent ',
#   'District': ' D25',
#   'Completion_Year': '2000 ',
#   'Leasehold': ' 99 years',
#   'Bedroom': '3',
#   'Bathroom': 3,
#   'Sqft': 1248,
#   'Sqm': 115.94},
#  {'Name': 'Sunshine Mansions',
#   'Price': 990000,
#   'Address': '289 Joo Chiat Place ',
#   'District': ' D15',
#   'Completion_Year': '2006 ',
#   'Leasehold': ' Freehold',
#   'Bedroom': '2',
#   'Bathroom': 2,
#   'Sqft': 790,
#   'Sqm': 73.39},
#  {'Name': 'A Treasure Trove',
#   'Price': 1280000,
#   'Address': '62 Punggol Walk ',
#   'District': ' D19',
#   'Completion_Year': '2015 ',
#   'Leasehold': ' 99 years',
#   'Bedroom': '3',
#   'Bathroom': 3,
#   'Sqft': 1044,
#   'Sqm': 96.99},
#  {'Name': 'Lakeville',
#   'Price': 1750000,
#   'Address': '11 Jurong Lake Link ',
#   'District': ' D22',
#   'Completion_Year': '2018 ',
#   'Leasehold': ' 99 years',
#   'Bedroom': '3',
#   'Bathroom': 3,
#   'Sqft': 1163,
#   'Sqm': 108.04},
#  {'Name': 'Roots @ Transit',
#   'Price': 1598000,
#   'Address': '9 Transit Road ',
#   'District': ' D26',
#   'Completion_Year': '2023 ',
#   'Leasehold': ' 99 years',
#   'Bedroom': '3',
#   'Bathroom': 2,
#   'Sqft': 1326,
#   'Sqm': 123.18},
#  {'Name': 'Queens Peak',
#   'Price': 1380000,
#   'Address': '1 Dundee Road ',
#   'District': ' D3',
#   'Completion_Year': '2020 ',
#   'Leasehold': ' 99 years',
#   'Bedroom': '2',
#   'Bathroom': 2,
#   'Sqft': 807,
#   'Sqm': 74.97},
#  {'Name': 'Waterview',
#   'Price': 1180000,
#   'Address': '85 Tampines Avenue 1 ',
#   'District': ' D18',
#   'Completion_Year': '2014 ',
#   'Leasehold': ' 99 years',
#   'Bedroom': '3',
#   'Bathroom': 3,
#   'Sqft': 1130,
#   'Sqm': 104.98},
#  {'Name': 'Sims Urban Oasis',
#   'Price': 1080000,
#   'Address': '8 Sims Drive ',
#   'District': ' D14',
#   'Completion_Year': '2020 ',
#   'Leasehold': ' 99 years',
#   'Bedroom': '2',
#   'Bathroom': 1,
#   'Sqft': 667,
#   'Sqm': 61.96},
#  {'Name': 'Sunrise Gardens',
#   'Price': 1600000,
#   'Address': '57 Sunrise Avenue ',
#   'District': ' D28',
#   'Completion_Year': '1998 ',
#   'Leasehold': ' 99 years',
#   'Bedroom': '4',
#   'Bathroom': 4,
#   'Sqft': 2024,
#   'Sqm': 188.03},
#  {'Name': 'The Arte',
#   'Price': 2590000,
#   'Address': '23 Jalan Raja Udang ',
#   'District': ' D12',
#   'Completion_Year': '2010 ',
#   'Leasehold': ' Freehold',
#   'Bedroom': '4',
#   'Bathroom': 4,
#   'Sqft': 1873,
#   'Sqm': 174.0},
#  {'Name': 'Robertson Edge',
#   'Price': 1680000,
#   'Address': '18 Tong Watt Road ',
#   'District': ' D9',
#   'Completion_Year': '2008 ',
#   'Leasehold': ' 999 years',
#   'Bedroom': '1',
#   'Bathroom': 2,
#   'Sqft': 904,
#   'Sqm': 83.98},
#  {'Name': 'Stellar Rv',
#   'Price': 1300000,
#   'Address': '408 River Valley Road ',
#   'District': ' D10',
#   'Completion_Year': '2015 ',
#   'Leasehold': ' Freehold',
#   'Bedroom': '2',
#   'Bathroom': 1,
#   'Sqft': 538,
#   'Sqm': 49.98},
#  {'Name': 'The Centris',
#   'Price': 1450000,
#   'Address': '75 Jurong West Central 3 ',
#   'District': ' D22',
#   'Completion_Year': '2009 ',
#   'Leasehold': ' 99 years',
#   'Bedroom': '2',
#   'Bathroom': 2,
#   'Sqft': 1292,
#   'Sqm': 120.03},
#  {'Name': 'The Topiary',
#   'Price': 1100000,
#   'Address': '19 Fernvale Lane ',
#   'District': ' D28',
#   'Completion_Year': '2016 ',
#   'Leasehold': ' 99 years',
#   'Bedroom': '3',
#   'Bathroom': 3,
#   'Sqft': 1044,
#   'Sqm': 96.99},
#  {'Name': 'The Wisteria',
#   'Price': 819999,
#   'Address': '592 Yishun Ring Road ',
#   'District': ' D27',
#   'Completion_Year': '2019 ',
#   'Leasehold': ' 99 years',
#   'Bedroom': '2',
#   'Bathroom': 2,
#   'Sqft': 710,
#   'Sqm': 65.96},
#  {'Name': 'Cardiff Residence',
#   'Price': 1190000,
#   'Address': '103 Cardiff Grove ',
#   'District': ' D19',
#   'Completion_Year': '2015 ',
#   'Leasehold': ' 99 years',
#   'Bedroom': '2',
#   'Bathroom': 2,
#   'Sqft': 1033,
#   'Sqm': 95.96},
#  {'Name': 'Wallich Residence',
#   'Price': 5488000,
#   'Address': '3 Wallich Street ',
#   'District': ' D2',
#   'Completion_Year': '2022 ',
#   'Leasehold': ' 99 years',
#   'Bedroom': '3',
#   'Bathroom': 3,
#   'Sqft': 1625,
#   'Sqm': 150.96},
#  {'Name': 'Caribbean At Keppel Bay',
#   'Price': 3900000,
#   'Address': '40 Keppel Bay Drive ',
#   'District': ' D4',
#   'Completion_Year': '2004 ',
#   'Leasehold': ' 99 years',
#   'Bedroom': '4',
#   'Bathroom': 4,
#   'Sqft': 3209,
#   'Sqm': 298.12},
#  {'Name': 'Eight Courtyards',
#   'Price': 978000,
#   'Address': '8 Canberra Drive ',
#   'District': ' D27',
#   'Completion_Year': '2014 ',
#   'Leasehold': ' 99 years',
#   'Bedroom': '3',
#   'Bathroom': 2,
#   'Sqft': 990,
#   'Sqm': 91.97},
#  {'Name': 'Rivertrees Residences',
#   'Price': 860000,
#   'Address': '21 Fernvale Close ',
#   'District': ' D28',
#   'Completion_Year': '2018 ',
#   'Leasehold': ' 99 years',
#   'Bedroom': '2',
#   'Bathroom': 2,
#   'Sqft': 700,
#   'Sqm': 65.03},
#  {'Name': 'Marina One Residences',
#   'Price': 1580000,
#   'Address': '21 Marina Way ',
#   'District': ' D1',
#   'Completion_Year': '2018 ',
#   'Leasehold': ' 99 years',
#   'Bedroom': '1',
#   'Bathroom': 1,
#   'Sqft': 775,
#   'Sqm': 71.99},
#  {'Name': '8 @ Woodleigh',
#   'Price': 750000,
#   'Address': '6 Woodleigh Close ',
#   'District': ' D13',
#   'Completion_Year': '2012 ',
#   'Leasehold': ' 99 years',
#   'Bedroom': 'Studio',
#   'Bathroom': 1,
#   'Sqft': 495,
#   'Sqm': 45.98},
#  {'Name': 'The Loft',
#   'Price': 2348000,
#   'Address': '22 Nassim Hill ',
#   'District': ' D10',
#   'Completion_Year': '2002 ',
#   'Leasehold': ' 99 years',
#   'Bedroom': '2',
#   'Bathroom': 3,
#   'Sqft': 1302,
#   'Sqm': 120.95},
#  {'Name': 'Reflections At Keppel Bay',
#   'Price': 2350000,
#   'Address': '23 Keppel Bay View ',
#   'District': ' D4',
#   'Completion_Year': '2011 ',
#   'Leasehold': ' 99 years',
#   'Bedroom': '3',
#   'Bathroom': 2,
#   'Sqft': 1496,
#   'Sqm': 138.98},
#  {'Name': 'Palm Gardens',
#   'Price': 915000,
#   'Address': '2B Hong San Walk ',
#   'District': ' D23',
#   'Completion_Year': '2000 ',
#   'Leasehold': ' 99 years',
#   'Bedroom': '3',
#   'Bathroom': 3,
#   'Sqft': 1216,
#   'Sqm': 112.97},
#  {'Name': 'Newton Edge',
#   'Price': 1320000,
#   'Address': '1 Makeway Avenue ',
#   'District': ' D9',
#   'Completion_Year': '2011 ',
#   'Leasehold': ' Freehold',
#   'Bedroom': '1',
#   'Bathroom': 1,
#   'Sqft': 743,
#   'Sqm': 69.02},
#  {'Name': 'Village @ Pasir Panjang',
#   'Price': 1320000,
#   'Address': '463 Pasir Panjang Road ',
#   'District': ' D5',
#   'Completion_Year': '2016 ',
#   'Leasehold': ' Freehold',
#   'Bedroom': '2',
#   'Bathroom': 2,
#   'Sqft': 839,
#   'Sqm': 77.94},
#  {'Name': 'City Loft',
#   'Price': 600000,
#   'Address': '363 Race Course Road ',
#   'District': ' D8',
#   'Completion_Year': '2011 ',
#   'Leasehold': ' Freehold',
#   'Bedroom': '1',
#   'Bathroom': 1,
#   'Sqft': 366,
#   'Sqm': 34.0},
#  {'Name': 'Emerald East',
#   'Price': 3200000,
#   'Address': '8D Tanjong Rhu Road ',
#   'District': ' D15',
#   'Completion_Year': '1999 ',
#   'Leasehold': ' Freehold',
#   'Bedroom': '4',
#   'Bathroom': 5,
#   'Sqft': 2077,
#   'Sqm': 192.95},
#  {'Name': 'Gem Residences',
#   'Price': 890000,
#   'Address': '1 Lorong 5 Toa Payoh ',
#   'District': ' D12',
#   'Completion_Year': '2020 ',
#   'Leasehold': ' 99 years',
#   'Bedroom': '1',
#   'Bathroom': 1,
#   'Sqft': 484,
#   'Sqm': 44.96},
#  {'Name': 'Palm Loft',
#   'Price': 1690000,
#   'Address': '136 Joo Chiat Terrace ',
#   'District': ' D15',
#   'Completion_Year': '2009 ',
#   'Leasehold': ' Freehold',
#   'Bedroom': '3',
#   'Bathroom': 2,
#   'Sqft': 1540,
#   'Sqm': 143.07},
#  {'Name': 'Suites @ Paya Lebar',
#   'Price': 600000,
#   'Address': '418 Upper Paya Lebar Road ',
#   'District': ' D19',
#   'Completion_Year': '2014 ',
#   'Leasehold': ' Freehold',
#   'Bedroom': '1',
#   'Bathroom': 1,
#   'Sqft': 398,
#   'Sqm': 36.97},
#  {'Name': 'Viva Vista',
#   'Price': 650000,
#   'Address': '3 South Buona Vista Road ',
#   'District': ' D5',
#   'Completion_Year': '2015 ',
#   'Leasehold': ' Freehold',
#   'Bedroom': '1',
#   'Bathroom': 1,
#   'Sqft': 377,
#   'Sqm': 35.02},
#  {'Name': 'Rezi 26',
#   'Price': 608888,
#   'Address': '5A Lorong 26 Geylang ',
#   'District': ' D14',
#   'Completion_Year': '2015 ',
#   'Leasehold': ' Freehold',
#   'Bedroom': '1',
#   'Bathroom': 1,
#   'Sqft': 441,
#   'Sqm': 40.97},
#  {'Name': 'Regal 35',
#   'Price': 1040000,
#   'Address': '15 Lorong 35 Geylang ',
#   'District': ' D14',
#   'Completion_Year': '2005 ',
#   'Leasehold': ' Freehold',
#   'Bedroom': '2',
#   'Bathroom': 2,
#   'Sqft': 947,
#   'Sqm': 87.97},
#  {'Name': 'Parc Vera',
#   'Price': 848000,
#   'Address': '8 Hougang Street 32 ',
#   'District': ' D19',
#   'Completion_Year': '2015 ',
#   'Leasehold': ' 99 years',
#   'Bedroom': '2',
#   'Bathroom': 2,
#   'Sqft': 710,
#   'Sqm': 65.96},
#  {'Name': 'Fulcrum',
#   'Price': 1680000,
#   'Address': '33 Fort Road ',
#   'District': ' D15',
#   'Completion_Year': '2016 ',
#   'Leasehold': ' Freehold',
#   'Bedroom': '2',
#   'Bathroom': 2,
#   'Sqft': 700,
#   'Sqm': 65.03},
#  {'Name': 'Robertson Edge',
#   'Price': 1480000,
#   'Address': '18 Tong Watt Road ',
#   'District': ' D9',
#   'Completion_Year': '2008 ',
#   'Leasehold': ' 999 years',
#   'Bedroom': '1',
#   'Bathroom': 2,
#   'Sqft': 872,
#   'Sqm': 81.01},
#  {'Name': 'The Trumps',
#   'Price': 1350000,
#   'Address': '1 Jalan Kembangan ',
#   'District': ' D14',
#   'Completion_Year': '2005 ',
#   'Leasehold': ' 99 years',
#   'Bedroom': '2',
#   'Bathroom': 2,
#   'Sqft': 980,
#   'Sqm': 91.04},
#  {'Name': 'Roots @ Transit',
#   'Price': 749000,
#   'Address': '9 Transit Road ',
#   'District': ' D26',
#   'Completion_Year': '2023 ',
#   'Leasehold': ' 99 years',
#   'Bedroom': '2',
#   'Bathroom': 1,
#   'Sqft': 667,
#   'Sqm': 61.96},
#  {'Name': 'Emerald Park',
#   'Price': 1300000,
#   'Address': '2 Indus Road ',
#   'District': ' D3',
#   'Completion_Year': '1993 ',
#   'Leasehold': ' 99 years',
#   'Bedroom': '2',
#   'Bathroom': 2,
#   'Sqft': 926,
#   'Sqm': 86.02},
#  {'Name': 'The Tennery',
#   'Price': 728000,
#   'Address': '5A Woodlands Road ',
#   'District': ' D23',
#   'Completion_Year': '2013 ',
#   'Leasehold': ' 99 years',
#   'Bedroom': '1',
#   'Bathroom': 1,
#   'Sqft': 624,
#   'Sqm': 57.97},
#  {'Name': 'Pine Grove',
#   'Price': 1650000,
#   'Address': '1P Pine Grove ',
#   'District': ' D21',
#   'Completion_Year': '1984 ',
#   'Leasehold': ' 99 years',
#   'Bedroom': '4',
#   'Bathroom': 3,
#   'Sqft': 1679,
#   'Sqm': 155.98},
#  {'Name': 'Bliss Regalia',
#   'Price': 850000,
#   'Address': '80 Sing Avenue ',
#   'District': ' D8',
#   'Completion_Year': '2010 ',
#   'Leasehold': ' Freehold',
#   'Bedroom': '1',
#   'Bathroom': 1,
#   'Sqft': 646,
#   'Sqm': 60.01},
#  {'Name': 'Le Quest',
#   'Price': 1150000,
#   'Address': '2 Bukit Batok Street 41 ',
#   'District': ' D23',
#   'Completion_Year': '2020 ',
#   'Leasehold': ' 99 years',
#   'Bedroom': '2',
#   'Bathroom': 1,
#   'Sqft': 614,
#   'Sqm': 57.04},
#  {'Name': 'The Coast At Sentosa Cove',
#   'Price': 3880000,
#   'Address': '280 Ocean Drive ',
#   'District': ' D4',
#   'Completion_Year': '2009 ',
#   'Leasehold': ' 99 years',
#   'Bedroom': '4',
#   'Bathroom': 4,
#   'Sqft': 2357,
#   'Sqm': 218.97},
#  {'Name': 'The Arcadia',
#   'Price': 3680000,
#   'Address': '237 Arcadia Road ',
#   'District': ' D11',
#   'Completion_Year': '1983 ',
#   'Leasehold': ' 99 years',
#   'Bedroom': '4',
#   'Bathroom': 4,
#   'Sqft': 3750,
#   'Sqm': 348.38},
#  {'Name': 'The Berth By The Cove',
#   'Price': 6998000,
#   'Address': '228 Ocean Drive ',
#   'District': ' D4',
#   'Completion_Year': '2006 ',
#   'Leasehold': ' 99 years',
#   'Bedroom': '4',
#   'Bathroom': 4,
#   'Sqft': 6028,
#   'Sqm': 560.01},
#  {'Name': 'The Estuary',
#   'Price': 1020000,
#   'Address': '89 Yishun Avenue 1 ',
#   'District': ' D27',
#   'Completion_Year': '2013 ',
#   'Leasehold': ' 99 years',
#   'Bedroom': '2',
#   'Bathroom': 2,
#   'Sqft': 1119,
#   'Sqm': 103.95},
#  {'Name': 'Flamingo Valley',
#   'Price': 2000000,
#   'Address': '468 Siglap Road ',
#   'District': ' D15',
#   'Completion_Year': '2014 ',
#   'Leasehold': ' Freehold',
#   'Bedroom': '3',
#   'Bathroom': 2,
#   'Sqft': 1937,
#   'Sqm': 179.95},
#  {'Name': 'Jewel @ Buangkok',
#   'Price': 1028000,
#   'Address': '85 Compassvale Bow ',
#   'District': ' D19',
#   'Completion_Year': '2017 ',
#   'Leasehold': ' 99 years',
#   'Bedroom': '2',
#   'Bathroom': 2,
#   'Sqft': 775,
#   'Sqm': 71.99},
#  {'Name': 'Symphony Suites',
#   'Price': 799999,
#   'Address': '21 Yishun Close ',
#   'District': ' D27',
#   'Completion_Year': '2019 ',
#   'Leasehold': ' 99 years',
#   'Bedroom': '2',
#   'Bathroom': 2,
#   'Sqft': 689,
#   'Sqm': 64.01},
#  {'Name': 'Hedges Park Condominium',
#   'Price': 790000,
#   'Address': '83 Flora Drive ',
#   'District': ' D17',
#   'Completion_Year': '2015 ',
#   'Leasehold': ' 99 years',
#   'Bedroom': '2',
#   'Bathroom': 2,
#   'Sqft': 797,
#   'Sqm': 74.04},
#  {'Name': 'Marina Bay Suites',
#   'Price': 28800000,
#   'Address': '3 Central Boulevard ',
#   'District': ' D1',
#   'Completion_Year': '2013 ',
#   'Leasehold': ' 99 years',
#   'Bedroom': '5',
#   'Bathroom': 7,
#   'Sqft': 8513,
#   'Sqm': 790.88},
#  {'Name': 'High Park Residences',
#   'Price': 1198000,
#   'Address': '21 Fernvale Road ',
#   'District': ' D28',
#   'Completion_Year': '2019 ',
#   'Leasehold': ' 99 years',
#   'Bedroom': '3',
#   'Bathroom': 3,
#   'Sqft': 990,
#   'Sqm': 91.97},
#  {'Name': 'Parc Sophia',
#   'Price': 1100000,
#   'Address': '8 Adis Road ',
#   'District': ' D9',
#   'Completion_Year': '2013 ',
#   'Leasehold': ' Freehold',
#   'Bedroom': '1',
#   'Bathroom': 1,
#   'Sqft': 667,
#   'Sqm': 61.96},
#  {'Name': '8 @ Mount Sophia',
#   'Price': 1450000,
#   'Address': '10 Mount Sophia ',
#   'District': ' D9',
#   'Completion_Year': '2007 ',
#   'Leasehold': ' 103 years',
#   'Bedroom': '2',
#   'Bathroom': 1,
#   'Sqft': 861,
#   'Sqm': 79.98},
#  {'Name': 'Vue 8 Residence',
#   'Price': 810000,
#   'Address': '89 Pasir Ris Heights ',
#   'District': ' D18',
#   'Completion_Year': '2017 ',
#   'Leasehold': ' 99 years',
#   'Bedroom': '2',
#   'Bathroom': 1,
#   'Sqft': 700,
#   'Sqm': 65.03},
#  {'Name': 'The Poiz Residences',
#   'Price': 750000,
#   'Address': '12 Meyappa Chettiar Road ',
#   'District': ' D13',
#   'Completion_Year': '2019 ',
#   'Leasehold': ' 99 years',
#   'Bedroom': 'Studio',
#   'Bathroom': 1,
#   'Sqft': 420,
#   'Sqm': 39.01},
#  {'Name': 'South Beach Residences',
#   'Price': 19050000,
#   'Address': '28 Beach Road ',
#   'District': ' D7',
#   'Completion_Year': '2016 ',
#   'Leasehold': ' 99 years',
#   'Bedroom': '4',
#   'Bathroom': 5,
#   'Sqft': 4446,
#   'Sqm': 413.04},
#  {'Name': 'La Casa',
#   'Price': 880000,
#   'Address': '50 Woodlands Drive 16 ',
#   'District': ' D25',
#   'Completion_Year': '2008 ',
#   'Leasehold': ' 99 years',
#   'Bedroom': '3',
#   'Bathroom': 2,
#   'Sqft': 1141,
#   'Sqm': 106.0},
#  {'Name': 'Gem Residences',
#   'Price': 1580000,
#   'Address': '3 Lorong 5 Toa Payoh ',
#   'District': ' D12',
#   'Completion_Year': '2020 ',
#   'Leasehold': ' 99 years',
#   'Bedroom': '3',
#   'Bathroom': 2,
#   'Sqft': 947,
#   'Sqm': 87.97},
#  {'Name': 'Icon',
#   'Price': 1180000,
#   'Address': '10 Gopeng Street ',
#   'District': ' D2',
#   'Completion_Year': '2007 ',
#   'Leasehold': ' 99 years',
#   'Bedroom': '1',
#   'Bathroom': 1,
#   'Sqft': 700,
#   'Sqm': 65.03},
#  {'Name': 'Parc Olympia',
#   'Price': 900000,
#   'Address': '54 Flora Drive ',
#   'District': ' D17',
#   'Completion_Year': '2015 ',
#   'Leasehold': ' 99 years',
#   'Bedroom': '2',
#   'Bathroom': 2,
#   'Sqft': 969,
#   'Sqm': 90.02},
#  {'Name': "L'viv",
#   'Price': 1350000,
#   'Address': '23 Newton Road ',
#   'District': ' D11',
#   'Completion_Year': '2013 ',
#   'Leasehold': ' Freehold',
#   'Bedroom': '1',
#   'Bathroom': 1,
#   'Sqft': 614,
#   'Sqm': 57.04},
#  {'Name': 'The Sorrento',
#   'Price': 1320000,
#   'Address': '55 West Coast Road ',
#   'District': ' D5',
#   'Completion_Year': '2015 ',
#   'Leasehold': ' Freehold',
#   'Bedroom': '2',
#   'Bathroom': 2,
#   'Sqft': 1065,
#   'Sqm': 98.94},
#  {'Name': '72 Grange',
#   'Price': 7550000,
#   'Address': '72 Grange Road ',
#   'District': ' D10',
#   'Completion_Year': '1995 ',
#   'Leasehold': ' Freehold',
#   'Bedroom': '4',
#   'Bathroom': 4,
#   'Sqft': 3875,
#   'Sqm': 359.99},
#  {'Name': 'Waterbank At Dakota',
#   'Price': 1680000,
#   'Address': '82 Dakota Crescent ',
#   'District': ' D14',
#   'Completion_Year': '2013 ',
#   'Leasehold': ' 99 years',
#   'Bedroom': '3',
#   'Bathroom': 2,
#   'Sqft': 1130,
#   'Sqm': 104.98},
#  {'Name': 'Citylights',
#   'Price': 1500000,
#   'Address': '90 Jellicoe Road ',
#   'District': ' D8',
#   'Completion_Year': '2007 ',
#   'Leasehold': ' 99 years',
#   'Bedroom': '2',
#   'Bathroom': 2,
#   'Sqft': 893,
#   'Sqm': 82.96},
#  {'Name': 'Mackenzie 88',
#   'Price': 790000,
#   'Address': '88 Mackenzie Road ',
#   'District': ' D9',
#   'Completion_Year': '2009 ',
#   'Leasehold': ' Freehold',
#   'Bedroom': '1',
#   'Bathroom': 1,
#   'Sqft': 463,
#   'Sqm': 43.01},
#  {'Name': 'Pebble Bay',
#   'Price': 2200000,
#   'Address': '134 Tanjong Rhu Road ',
#   'District': ' D15',
#   'Completion_Year': '1997 ',
#   'Leasehold': ' 99 years',
#   'Bedroom': '2',
#   'Bathroom': 3,
#   'Sqft': 1378,
#   'Sqm': 128.02},
#  {'Name': 'Marina One Residences',
#   'Price': 2471812,
#   'Address': '23 Marina Way ',
#   'District': ' D1',
#   'Completion_Year': '2018 ',
#   'Leasehold': ' 99 years',
#   'Bedroom': '2',
#   'Bathroom': 2,
#   'Sqft': 1066,
#   'Sqm': 99.03},
#  {'Name': 'Nouvelle Park',
#   'Price': 1428000,
#   'Address': '133 Poh Huat Road West ',
#   'District': ' D19',
#   'Completion_Year': '1994 ',
#   'Leasehold': ' Freehold',
#   'Bedroom': '3',
#   'Bathroom': 3,
#   'Sqft': 1495,
#   'Sqm': 138.88},
#  {'Name': 'Riverbank @ Fernvale',
#   'Price': 1180000,
#   'Address': '11 Fernvale Close ',
#   'District': ' D28',
#   'Completion_Year': '2018 ',
#   'Leasehold': ' 99 years',
#   'Bedroom': '3',
#   'Bathroom': 3,
#   'Sqft': 1044,
#   'Sqm': 96.99},
#  {'Name': 'Symphony Suites',
#   'Price': 798000,
#   'Address': '15 Yishun Close ',
#   'District': ' D27',
#   'Completion_Year': '2019 ',
#   'Leasehold': ' 99 years',
#   'Bedroom': '2',
#   'Bathroom': 2,
#   'Sqft': 689,
#   'Sqm': 64.01},
#  {'Name': 'Eco',
#   'Price': 1090000,
#   'Address': '283 Bedok South Avenue 3 ',
#   'District': ' D16',
#   'Completion_Year': '2017 ',
#   'Leasehold': ' 99 years',
#   'Bedroom': '2',
#   'Bathroom': 1,
#   'Sqft': 775,
#   'Sqm': 71.99},
#  {'Name': 'Palm Galleria',
#   'Price': 750000,
#   'Address': '78 Lorong K Telok Kurau ',
#   'District': ' D15',
#   'Completion_Year': '2010 ',
#   'Leasehold': ' Freehold',
#   'Bedroom': '1',
#   'Bathroom': 1,
#   'Sqft': 495,
#   'Sqm': 45.98},
#  {'Name': 'Principal Garden',
#   'Price': 1399000,
#   'Address': '93 Prince Charles Crescent ',
#   'District': ' D3',
#   'Completion_Year': '2019 ',
#   'Leasehold': ' 99 years',
#   'Bedroom': '2',
#   'Bathroom': 2,
#   'Sqft': 765,
#   'Sqm': 71.07},
#  {'Name': 'The Mint Residences',
#   'Price': 1080000,
#   'Address': '180 Joo Chiat Terrace ',
#   'District': ' D15',
#   'Completion_Year': '2009 ',
#   'Leasehold': ' Freehold',
#   'Bedroom': '2',
#   'Bathroom': 2,
#   'Sqft': 872,
#   'Sqm': 81.01},
#  {'Name': 'Dakota Residences',
#   'Price': 1880000,
#   'Address': '34 Dakota Crescent ',
#   'District': ' D14',
#   'Completion_Year': '2010 ',
#   'Leasehold': ' 99 years',
#   'Bedroom': '3',
#   'Bathroom': 3,
#   'Sqft': 1313,
#   'Sqm': 121.98},
#  {'Name': 'Eight Riversuites',
#   'Price': 780000,
#   'Address': '6 Whampoa East ',
#   'District': ' D12',
#   'Completion_Year': '2016 ',
#   'Leasehold': ' 99 years',
#   'Bedroom': '1',
#   'Bathroom': 1,
#   'Sqft': 441,
#   'Sqm': 40.97},
#  {'Name': 'The Line @ Tanjong Rhu',
#   'Price': 1050000,
#   'Address': '6 Tanjong Rhu Road ',
#   'District': ' D15',
#   'Completion_Year': '2016 ',
#   'Leasehold': ' Freehold',
#   'Bedroom': '1',
#   'Bathroom': 1,
#   'Sqft': 420,
#   'Sqm': 39.01},
#  {'Name': 'Lumiere',
#   'Price': 1100000,
#   'Address': '2 Mistri Road ',
#   'District': ' D2',
#   'Completion_Year': '2010 ',
#   'Leasehold': ' 99 years',
#   'Bedroom': '1',
#   'Bathroom': 1,
#   'Sqft': 624,
#   'Sqm': 57.97},
#  {'Name': 'Nouvel 18',
#   'Price': 5752000,
#   'Address': '16 Anderson Road ',
#   'District': ' D10',
#   'Completion_Year': '2014 ',
#   'Leasehold': ' Freehold',
#   'Bedroom': '3',
#   'Bathroom': 3,
#   'Sqft': 1765,
#   'Sqm': 163.97},
#  {'Name': 'Citylights',
#   'Price': 1080000,
#   'Address': '88 Jellicoe Road ',
#   'District': ' D8',
#   'Completion_Year': '2007 ',
#   'Leasehold': ' 99 years',
#   'Bedroom': '1',
#   'Bathroom': 1,
#   'Sqft': 592,
#   'Sqm': 54.99},
#  {'Name': 'The Venue Residences',
#   'Price': 1980000,
#   'Address': '6 Tai Thong Crescent ',
#   'District': ' D13',
#   'Completion_Year': '2017 ',
#   'Leasehold': ' 99 years',
#   'Bedroom': '4',
#   'Bathroom': 2,
#   'Sqft': 1238,
#   'Sqm': 115.01},
#  {'Name': 'Tiara',
#   'Price': 3150000,
#   'Address': '1 Kim Seng Walk ',
#   'District': ' D9',
#   'Completion_Year': '1995 ',
#   'Leasehold': ' Freehold',
#   'Bedroom': '3',
#   'Bathroom': 3,
#   'Sqft': 1507,
#   'Sqm': 140.0},
#  {'Name': 'Parkview Apartments',
#   'Price': 860000,
#   'Address': '5 Bukit Batok Street 25 ',
#   'District': ' D23',
#   'Completion_Year': '1998 ',
#   'Leasehold': ' 99 years',
#   'Bedroom': '3',
#   'Bathroom': 3,
#   'Sqft': 1119,
#   'Sqm': 103.95},
#  {'Name': 'The Estuary',
#   'Price': 1200000,
#   'Address': '91 Yishun Avenue 1 ',
#   'District': ' D27',
#   'Completion_Year': '2013 ',
#   'Leasehold': ' 99 years',
#   'Bedroom': '2',
#   'Bathroom': 2,
#   'Sqft': 1119,
#   'Sqm': 103.95},
#  {'Name': 'Riverbank @ Fernvale',
#   'Price': 1060000,
#   'Address': '11 Fernvale Close ',
#   'District': ' D28',
#   'Completion_Year': '2018 ',
#   'Leasehold': ' 99 years',
#   'Bedroom': '3',
#   'Bathroom': 2,
#   'Sqft': 947,
#   'Sqm': 87.97},
#  {'Name': 'Seletar Park Residence',
#   'Price': 1250000,
#   'Address': '21 Seletar Road ',
#   'District': ' D28',
#   'Completion_Year': '2015 ',
#   'Leasehold': ' 99 years',
#   'Bedroom': '2',
#   'Bathroom': 2,
#   'Sqft': 1012,
#   'Sqm': 94.01},
#  {'Name': 'The Foresta @ Mount Faber',
#   'Price': 1450000,
#   'Address': '102 Wishart Road ',
#   'District': ' D4',
#   'Completion_Year': '2014 ',
#   'Leasehold': ' Freehold',
#   'Bedroom': '2',
#   'Bathroom': 2,
#   'Sqft': 775,
#   'Sqm': 71.99},
#  {'Name': 'Palm Gardens',
#   'Price': 990000,
#   'Address': '2C Hong San Walk ',
#   'District': ' D23',
#   'Completion_Year': '2000 ',
#   'Leasehold': ' 99 years',
#   'Bedroom': '4',
#   'Bathroom': 3,
#   'Sqft': 1346,
#   'Sqm': 125.04},
#  {'Name': 'Sea Esta',
#   'Price': 1290000,
#   'Address': '20 Pasir Ris Link ',
#   'District': ' D18',
#   'Completion_Year': '2015 ',
#   'Leasehold': ' 99 years',
#   'Bedroom': '3',
#   'Bathroom': 3,
#   'Sqft': 1206,
#   'Sqm': 112.04},
#  {'Name': 'Coco Palms',
#   'Price': 1680000,
#   'Address': '23 Pasir Ris Grove ',
#   'District': ' D18',
#   'Completion_Year': '2019 ',
#   'Leasehold': ' 99 years',
#   'Bedroom': '4',
#   'Bathroom': 3,
#   'Sqft': 1259,
#   'Sqm': 116.96},
#  {'Name': 'Marine Blue',
#   'Price': 2150000,
#   'Address': '89 Marine Parade Road ',
#   'District': ' D15',
#   'Completion_Year': '2016 ',
#   'Leasehold': ' Freehold',
#   'Bedroom': '2',
#   'Bathroom': 2,
#   'Sqft': 1141,
#   'Sqm': 106.0},
#  {'Name': 'Jui Residences',
#   'Price': 1702368,
#   'Address': '1177 Serangoon Road ',
#   'District': ' D12',
#   'Completion_Year': '2022 ',
#   'Leasehold': ' Freehold',
#   'Bedroom': '3',
#   'Bathroom': 2,
#   'Sqft': 947,
#   'Sqm': 87.97},
#  {'Name': 'Stars Of Kovan',
#   'Price': 1320000,
#   'Address': '980 Upper Serangoon Road ',
#   'District': ' D19',
#   'Completion_Year': '2020 ',
#   'Leasehold': ' 99 years',
#   'Bedroom': '2',
#   'Bathroom': 2,
#   'Sqft': 743,
#   'Sqm': 69.02},
#  {'Name': 'Jui Residences',
#   'Price': 1806196,
#   'Address': '1177 Serangoon Road ',
#   'District': ' D12',
#   'Completion_Year': '2022 ',
#   'Leasehold': ' Freehold',
#   'Bedroom': '3',
#   'Bathroom': 2,
#   'Sqft': 947,
#   'Sqm': 87.97},
#  {'Name': 'Kensington Square',
#   'Price': 725000,
#   'Address': '2 Jalan Lokam ',
#   'District': ' D19',
#   'Completion_Year': '2017 ',
#   'Leasehold': ' Freehold',
#   'Bedroom': '1',
#   'Bathroom': 1,
#   'Sqft': 431,
#   'Sqm': 40.04},
#  {'Name': 'Eight Riversuites',
#   'Price': 1060000,
#   'Address': '10 Whampoa East ',
#   'District': ' D12',
#   'Completion_Year': '2016 ',
#   'Leasehold': ' 99 years',
#   'Bedroom': '1',
#   'Bathroom': 2,
#   'Sqft': 818,
#   'Sqm': 75.99},
#  {'Name': 'Riverfront Residences',
#   'Price': 1965000,
#   'Address': '43 Hougang Avenue 7 ',
#   'District': ' D19',
#   'Completion_Year': '2024 ',
#   'Leasehold': ' 99 years',
#   'Bedroom': '4',
#   'Bathroom': 4,
#   'Sqft': 1485,
#   'Sqm': 137.96},
#  {'Name': 'Stirling Residences',
#   'Price': 1275000,
#   'Address': '21 Stirling Road ',
#   'District': ' D0',
#   'Completion_Year': '2022 ',
#   'Leasehold': ' 99 years',
#   'Bedroom': '2',
#   'Bathroom': 1,
#   'Sqft': 624,
#   'Sqm': 57.97},
#  {'Name': 'Casa Cambio',
#   'Price': 688000,
#   'Address': '9 Lim Tua Tow Road ',
#   'District': ' D19',
#   'Completion_Year': '2015 ',
#   'Leasehold': ' Freehold',
#   'Bedroom': '1',
#   'Bathroom': 1,
#   'Sqft': 431,
#   'Sqm': 40.04},
#  {'Name': 'Twin Waterfalls',
#   'Price': 1100000,
#   'Address': '104 Punggol Walk ',
#   'District': ' D19',
#   'Completion_Year': '2015 ',
#   'Leasehold': ' 99 years',
#   'Bedroom': '3',
#   'Bathroom': 3,
#   'Sqft': 1109,
#   'Sqm': 103.02},
#  {'Name': 'The Linq @ Beauty World',
#   'Price': 2199999,
#   'Address': '118 Upper Bukit Timah Road ',
#   'District': ' D21',
#   'Completion_Year': '2023 ',
#   'Leasehold': ' Freehold',
#   'Bedroom': '3',
#   'Bathroom': 2,
#   'Sqft': 958,
#   'Sqm': 89.0},
#  {'Name': 'Daisy Suites',
#   'Price': 1100000,
#   'Address': '35 Daisy Road ',
#   'District': ' D13',
#   'Completion_Year': '2015 ',
#   'Leasehold': ' Freehold',
#   'Bedroom': '3',
#   'Bathroom': 2,
#   'Sqft': 861,
#   'Sqm': 79.98},
#  {'Name': 'Boathouse Residences',
#   'Price': 950000,
#   'Address': '33 Upper Serangoon View ',
#   'District': ' D19',
#   'Completion_Year': '2015 ',
#   'Leasehold': ' 99 years',
#   'Bedroom': '2',
#   'Bathroom': 2,
#   'Sqft': 840,
#   'Sqm': 78.03},
#  {'Name': 'Parc Riviera',
#   'Price': 1070000,
#   'Address': '101 West Coast Vale ',
#   'District': ' D5',
#   'Completion_Year': '2020 ',
#   'Leasehold': ' 99 years',
#   'Bedroom': '2',
#   'Bathroom': 2,
#   'Sqft': 710,
#   'Sqm': 65.96},
#  {'Name': 'The Line @ Tanjong Rhu',
#   'Price': 5460000,
#   'Address': '6 Tanjong Rhu Road ',
#   'District': ' D15',
#   'Completion_Year': '2016 ',
#   'Leasehold': ' Freehold',
#   'Bedroom': '4',
#   'Bathroom': 3,
#   'Sqft': 2325,
#   'Sqm': 215.99},
#  {'Name': 'Le Reve',
#   'Price': 1150000,
#   'Address': '33 Kampong Eunos ',
#   'District': ' D14',
#   'Completion_Year': '2008 ',
#   'Leasehold': ' Freehold',
#   'Bedroom': '2',
#   'Bathroom': 2,
#   'Sqft': 807,
#   'Sqm': 74.97},
#  {'Name': 'Park Place Residences',
#   'Price': 999900,
#   'Address': '6 Paya Lebar Road ',
#   'District': ' D14',
#   'Completion_Year': '2020 ',
#   'Leasehold': ' 99 years',
#   'Bedroom': '1',
#   'Bathroom': 1,
#   'Sqft': 484,
#   'Sqm': 44.96},
#  {'Name': 'East Meadows',
#   'Price': 1230000,
#   'Address': '34 Tanah Merah Kechil Road ',
#   'District': ' D16',
#   'Completion_Year': '2001 ',
#   'Leasehold': ' 99 years',
#   'Bedroom': '3',
#   'Bathroom': 3,
#   'Sqft': 1195,
#   'Sqm': 111.01},
#  {'Name': 'Optima @ Tanah Merah',
#   'Price': 1040000,
#   'Address': '78 Tanah Merah Kechil Avenue ',
#   'District': ' D16',
#   'Completion_Year': '2012 ',
#   'Leasehold': ' 99 years',
#   'Bedroom': '2',
#   'Bathroom': 2,
#   'Sqft': 861,
#   'Sqm': 79.98},
#  {'Name': "Grand Duchess At St. Patrick's",
#   'Price': 2500000,
#   'Address': "136 Saint Patrick's Road ",
#   'District': ' D15',
#   'Completion_Year': '2010 ',
#   'Leasehold': ' Freehold',
#   'Bedroom': '3',
#   'Bathroom': 3,
#   'Sqft': 1357,
#   'Sqm': 126.06},
#  {'Name': 'Tree House',
#   'Price': 940000,
#   'Address': '60 Chestnut Avenue ',
#   'District': ' D23',
#   'Completion_Year': '2013 ',
#   'Leasehold': ' 99 years',
#   'Bedroom': '2',
#   'Bathroom': 2,
#   'Sqft': 807,
#   'Sqm': 74.97},
#  {'Name': 'Coco Palms',
#   'Price': 1680000,
#   'Address': '23 Pasir Ris Grove ',
#   'District': ' D18',
#   'Completion_Year': '2019 ',
#   'Leasehold': ' 99 years',
#   'Bedroom': '4',
#   'Bathroom': 3,
#   'Sqft': 1259,
#   'Sqm': 116.96},
#  {'Name': 'Parc Olympia',
#   'Price': 1680000,
#   'Address': '64 Flora Drive ',
#   'District': ' D17',
#   'Completion_Year': '2015 ',
#   'Leasehold': ' 99 years',
#   'Bedroom': '3',
#   'Bathroom': 4,
#   'Sqft': 2164,
#   'Sqm': 201.04},
#  {'Name': '26 Newton',
#   'Price': 1300000,
#   'Address': '26 Newton Road ',
#   'District': ' D11',
#   'Completion_Year': '2016 ',
#   'Leasehold': ' Freehold',
#   'Bedroom': 'Na',
#   'Bathroom': 0,
#   'Sqft': 474,
#   'Sqm': 44.03},
#  {'Name': 'Symphony Suites',
#   'Price': 980000,
#   'Address': '15 Yishun Close ',
#   'District': ' D27',
#   'Completion_Year': '2019 ',
#   'Leasehold': ' 99 years',
#   'Bedroom': '3',
#   'Bathroom': 2,
#   'Sqft': 786,
#   'Sqm': 73.02},
#  {'Name': 'Waterbank At Dakota',
#   'Price': 1600000,
#   'Address': '70 Dakota Crescent ',
#   'District': ' D14',
#   'Completion_Year': '2013 ',
#   'Leasehold': ' 99 years',
#   'Bedroom': '2',
#   'Bathroom': 2,
#   'Sqft': 1420,
#   'Sqm': 131.92},
#  {'Name': 'Eight Courtyards',
#   'Price': 580000,
#   'Address': '14 Canberra Drive ',
#   'District': ' D27',
#   'Completion_Year': '2014 ',
#   'Leasehold': ' 99 years',
#   'Bedroom': '1',
#   'Bathroom': 1,
#   'Sqft': 452,
#   'Sqm': 41.99},
#  {'Name': 'Fulcrum',
#   'Price': 1700000,
#   'Address': '33 Fort Road ',
#   'District': ' D15',
#   'Completion_Year': '2016 ',
#   'Leasehold': ' Freehold',
#   'Bedroom': '2',
#   'Bathroom': 2,
#   'Sqft': 678,
#   'Sqm': 62.98},
#  {'Name': 'Artra',
#   'Price': 1650000,
#   'Address': '10 Alexandra View ',
#   'District': ' D3',
#   'Completion_Year': '2021 ',
#   'Leasehold': ' 99 years',
#   'Bedroom': '2',
#   'Bathroom': 2,
#   'Sqft': 829,
#   'Sqm': 77.01},
#  {'Name': 'H2O Residences',
#   'Price': 890000,
#   'Address': '40 Fernvale Link ',
#   'District': ' D28',
#   'Completion_Year': '2015 ',
#   'Leasehold': ' 99 years',
#   'Bedroom': '2',
#   'Bathroom': 2,
#   'Sqft': 883,
#   'Sqm': 82.03},
#  {'Name': 'Eight Courtyards',
#   'Price': 850000,
#   'Address': '10 Canberra Drive ',
#   'District': ' D27',
#   'Completion_Year': '2014 ',
#   'Leasehold': ' 99 years',
#   'Bedroom': '2',
#   'Bathroom': 2,
#   'Sqft': 861,
#   'Sqm': 79.98},
#  {'Name': 'Kovan Regency',
#   'Price': 1200000,
#   'Address': '38 Kovan Rise ',
#   'District': ' D19',
#   'Completion_Year': '2015 ',
#   'Leasehold': ' 99 years',
#   'Bedroom': '2',
#   'Bathroom': 2,
#   'Sqft': 775,
#   'Sqm': 71.99},
#  {'Name': 'The Tropica',
#   'Price': 1150000,
#   'Address': '51 Tampines Avenue 1 ',
#   'District': ' D18',
#   'Completion_Year': '2000 ',
#   'Leasehold': ' 99 years',
#   'Bedroom': '3',
#   'Bathroom': 3,
#   'Sqft': 1238,
#   'Sqm': 115.01},
#  {'Name': 'The Lakefront Residences',
#   'Price': 718000,
#   'Address': '48 Lakeside Drive ',
#   'District': ' D0',
#   'Completion_Year': '2014 ',
#   'Leasehold': ' 99 years',
#   'Bedroom': '1',
#   'Bathroom': 1,
#   'Sqft': 495,
#   'Sqm': 45.98},
#  {'Name': 'The Tampines Trilliant',
#   'Price': 928000,
#   'Address': '29 Tampines Central 7 ',
#   'District': ' D18',
#   'Completion_Year': '2015 ',
#   'Leasehold': ' 99 years',
#   'Bedroom': '3',
#   'Bathroom': 2,
#   'Sqft': 872,
#   'Sqm': 81.01},
#  {'Name': 'Fulcrum',
#   'Price': 1700000,
#   'Address': '33 Fort Road ',
#   'District': ' D15',
#   'Completion_Year': '2016 ',
#   'Leasehold': ' Freehold',
#   'Bedroom': '2',
#   'Bathroom': 2,
#   'Sqft': 678,
#   'Sqm': 62.98},
#  {'Name': 'Riviere',
#   'Price': 2908360,
#   'Address': '1 Jiak Kim Street ',
#   'District': ' D3',
#   'Completion_Year': '2023 ',
#   'Leasehold': ' 99 years',
#   'Bedroom': '3',
#   'Bathroom': 2,
#   'Sqft': 1141,
#   'Sqm': 106.0},
#  {'Name': 'The Skywoods',
#   'Price': 780000,
#   'Address': '13 Dairy Farm Heights ',
#   'District': ' D23',
#   'Completion_Year': '2016 ',
#   'Leasehold': ' 99 years',
#   'Bedroom': '1',
#   'Bathroom': 1,
#   'Sqft': 527,
#   'Sqm': 48.95},
#  {'Name': '8 St Thomas',
#   'Price': 5543000,
#   'Address': '10 Saint Thomas Walk ',
#   'District': ' D9',
#   'Completion_Year': '2018 ',
#   'Leasehold': ' Freehold',
#   'Bedroom': '4',
#   'Bathroom': 3,
#   'Sqft': 1744,
#   'Sqm': 162.02},
#  {'Name': 'Tiong Bahru Estate',
#   'Price': 1650000,
#   'Address': '10 Eng Hoon Street ',
#   'District': ' D3',
#   'Completion_Year': ' ',
#   'Leasehold': ' 99 years',
#   'Bedroom': '3',
#   'Bathroom': 2,
#   'Sqft': 1330,
#   'Sqm': 123.56},
#  {'Name': 'Cubik',
#   'Price': 1500000,
#   'Address': '81 Lorong K Telok Kurau ',
#   'District': ' D15',
#   'Completion_Year': '2011 ',
#   'Leasehold': ' Freehold',
#   'Bedroom': '3',
#   'Bathroom': 2,
#   'Sqft': 1119,
#   'Sqm': 103.95},
#  {'Name': 'Casa Cambio',
#   'Price': 678000,
#   'Address': '11 Lim Tua Tow Road ',
#   'District': ' D0',
#   'Completion_Year': '2015 ',
#   'Leasehold': ' Freehold',
#   'Bedroom': '1',
#   'Bathroom': 1,
#   'Sqft': 420,
#   'Sqm': 39.01},
#  {'Name': 'Zenith',
#   'Price': 1100000,
#   'Address': '60 Zion Road ',
#   'District': ' D10',
#   'Completion_Year': '2011 ',
#   'Leasehold': ' 999 years',
#   'Bedroom': '1',
#   'Bathroom': 1,
#   'Sqft': 474,
#   'Sqm': 44.03},
#  {'Name': "King's Arcade",
#   'Price': 2050000,
#   'Address': '559 Bukit Timah Road ',
#   'District': ' D10',
#   'Completion_Year': '2002 ',
#   'Leasehold': ' Freehold',
#   'Bedroom': '2',
#   'Bathroom': 2,
#   'Sqft': 1700,
#   'Sqm': 157.93},
#  {'Name': 'Soleil @ Sinaran',
#   'Price': 1130000,
#   'Address': '2 Sinaran Drive ',
#   'District': ' D11',
#   'Completion_Year': '2011 ',
#   'Leasehold': ' 99 years',
#   'Bedroom': 'Studio',
#   'Bathroom': 1,
#   'Sqft': 581,
#   'Sqm': 53.97},
#  {'Name': 'The Palette',
#   'Price': 1240000,
#   'Address': '109 Pasir Ris Grove ',
#   'District': ' D0',
#   'Completion_Year': '2015 ',
#   'Leasehold': ' 99 years',
#   'Bedroom': '3',
#   'Bathroom': 2,
#   'Sqft': 1152,
#   'Sqm': 107.02},
#  {'Name': 'The Tennery',
#   'Price': 1100000,
#   'Address': '5 Woodlands Road ',
#   'District': ' D23',
#   'Completion_Year': '2013 ',
#   'Leasehold': ' 99 years',
#   'Bedroom': '2',
#   'Bathroom': 2,
#   'Sqft': 937,
#   'Sqm': 87.05},
#  {'Name': 'Treasure at Tampines',
#   'Price': 1315000,
#   'Address': '1 Tampines Lane ',
#   'District': ' D18',
#   'Completion_Year': '2023 ',
#   'Leasehold': ' 99 years',
#   'Bedroom': '3',
#   'Bathroom': 2,
#   'Sqft': 1033,
#   'Sqm': 95.96},
#  {'Name': 'Ola',
#   'Price': 1538000,
#   'Address': '70 Anchorvale Crescent ',
#   'District': ' D19',
#   'Completion_Year': '2024 ',
#   'Leasehold': ' 99 years',
#   'Bedroom': '4',
#   'Bathroom': 4,
#   'Sqft': 1389,
#   'Sqm': 129.04},
#  {'Name': 'Parbury Hill Condominium',
#   'Price': 1750000,
#   'Address': '36 Parbury Avenue ',
#   'District': ' D0',
#   'Completion_Year': '1998 ',
#   'Leasehold': ' Freehold',
#   'Bedroom': '3',
#   'Bathroom': 2,
#   'Sqft': 1238,
#   'Sqm': 115.01},
#  {'Name': 'Mabelle',
#   'Price': 1550000,
#   'Address': '15 Lorong M Telok Kurau ',
#   'District': ' D15',
#   'Completion_Year': '2009 ',
#   'Leasehold': ' Freehold',
#   'Bedroom': '2',
#   'Bathroom': 2,
#   'Sqft': 1119,
#   'Sqm': 103.95},
#  {'Name': 'Penrose',
#   'Price': 788000,
#   'Address': '28 Sims Drive ',
#   'District': ' D14',
#   'Completion_Year': '2024 ',
#   'Leasehold': ' 99 years',
#   'Bedroom': '1',
#   'Bathroom': 1,
#   'Sqft': 473,
#   'Sqm': 43.94},
#  {'Name': 'Penrose',
#   'Price': 943000,
#   'Address': '28 Sims Drive ',
#   'District': ' D14',
#   'Completion_Year': '2024 ',
#   'Leasehold': ' 99 years',
#   'Bedroom': '2',
#   'Bathroom': 1,
#   'Sqft': 645,
#   'Sqm': 59.92},
#  {'Name': 'Penrose',
#   'Price': 1326000,
#   'Address': '28 Sims Drive ',
#   'District': ' D14',
#   'Completion_Year': '2024 ',
#   'Leasehold': ' 99 years',
#   'Bedroom': '3',
#   'Bathroom': 2,
#   'Sqft': 936,
#   'Sqm': 86.95},
#  {'Name': 'Penrose',
#   'Price': 2111000,
#   'Address': '28 Sims Drive ',
#   'District': ' D14',
#   'Completion_Year': '2024 ',
#   'Leasehold': ' 99 years',
#   'Bedroom': '4',
#   'Bathroom': 3,
#   'Sqft': 1388,
#   'Sqm': 128.94},
#  {'Name': 'The Tennery',
#   'Price': 740000,
#   'Address': '5A Woodlands Road ',
#   'District': ' D23',
#   'Completion_Year': '2013 ',
#   'Leasehold': ' 99 years',
#   'Bedroom': '1',
#   'Bathroom': 1,
#   'Sqft': 614,
#   'Sqm': 57.04},
#  {'Name': 'Kingsford Waterbay',
#   'Price': 610000,
#   'Address': '52 Upper Serangoon View ',
#   'District': ' D19',
#   'Completion_Year': '2018 ',
#   'Leasehold': ' 99 years',
#   'Bedroom': '1',
#   'Bathroom': 1,
#   'Sqft': 484,
#   'Sqm': 44.96},
#  {'Name': 'Mont Botanik Residence',
#   'Price': 1591200,
#   'Address': '2L Jalan Remaja ',
#   'District': ' D23',
#   'Completion_Year': '2022 ',
#   'Leasehold': ' Freehold',
#   'Bedroom': '3',
#   'Bathroom': 2,
#   'Sqft': 948,
#   'Sqm': 88.07},
#  {'Name': 'Whistler Grand',
#   'Price': 938400,
#   'Address': '107 West Coast Vale ',
#   'District': ' D5',
#   'Completion_Year': '2022 ',
#   'Leasehold': ' 99 years',
#   'Bedroom': '2',
#   'Bathroom': 1,
#   'Sqft': 614,
#   'Sqm': 57.04},
#  {'Name': 'Parc Clematis',
#   'Price': 1145000,
#   'Address': '2 Jalan Lempeng ',
#   'District': ' D5',
#   'Completion_Year': '2023 ',
#   'Leasehold': ' 99 years',
#   'Bedroom': '2',
#   'Bathroom': 2,
#   'Sqft': 721,
#   'Sqm': 66.98},
#  {'Name': 'Haus on Handy',
#   'Price': 1278400,
#   'Address': '28 Handy Road ',
#   'District': ' D9',
#   'Completion_Year': '2023 ',
#   'Leasehold': ' 99 years',
#   'Bedroom': '1',
#   'Bathroom': 1,
#   'Sqft': 452,
#   'Sqm': 41.99},
#  {'Name': 'Mayfair Modern',
#   'Price': 1359800,
#   'Address': '6 Rifle Range Road ',
#   'District': ' D21',
#   'Completion_Year': '2024 ',
#   'Leasehold': ' 99 years',
#   'Bedroom': '2',
#   'Bathroom': 1,
#   'Sqft': 624,
#   'Sqm': 57.97},
#  {'Name': 'Jui Residences',
#   'Price': 1550000,
#   'Address': '1177 Serangoon Road ',
#   'District': ' D12',
#   'Completion_Year': '2022 ',
#   'Leasehold': ' Freehold',
#   'Bedroom': '3',
#   'Bathroom': 2,
#   'Sqft': 883,
#   'Sqm': 82.03},
#  {'Name': 'Forett @ Bukit Timah',
#   'Price': 1752000,
#   'Address': '36 Toh Tuck Road ',
#   'District': ' D21',
#   'Completion_Year': '2023 ',
#   'Leasehold': ' Freehold',
#   'Bedroom': '3',
#   'Bathroom': 2,
#   'Sqft': 947,
#   'Sqm': 87.97},
#  {'Name': 'Rezi 24',
#   'Price': 738930,
#   'Address': '39 Lorong 24 Geylang ',
#   'District': ' D14',
#   'Completion_Year': '2022 ',
#   'Leasehold': ' Freehold',
#   'Bedroom': '1',
#   'Bathroom': 1,
#   'Sqft': 452,
#   'Sqm': 41.99},
#  {'Name': 'Royalgreen',
#   'Price': 1668000,
#   'Address': '2 Anamalai Avenue ',
#   'District': ' D10',
#   'Completion_Year': '2025 ',
#   'Leasehold': ' Freehold',
#   'Bedroom': '2',
#   'Bathroom': 1,
#   'Sqft': 635,
#   'Sqm': 58.99},
#  {'Name': 'Forett @ Bukit Timah',
#   'Price': 1175000,
#   'Address': '34 Toh Tuck Road ',
#   'District': ' D21',
#   'Completion_Year': '2023 ',
#   'Leasehold': ' Freehold',
#   'Bedroom': '2',
#   'Bathroom': 1,
#   'Sqft': 570,
#   'Sqm': 52.95},
#  {'Name': '120 Grange',
#   'Price': 2217000,
#   'Address': '120 Grange Road ',
#   'District': ' D10',
#   'Completion_Year': '2021 ',
#   'Leasehold': ' Freehold',
#   'Bedroom': '2',
#   'Bathroom': 2,
#   'Sqft': 678,
#   'Sqm': 62.98},
#  {'Name': 'The Verandah Residences',
#   'Price': 2242640,
#   'Address': '231 Pasir Panjang Road ',
#   'District': ' D5',
#   'Completion_Year': '2023 ',
#   'Leasehold': ' Freehold',
#   'Bedroom': '4',
#   'Bathroom': 2,
#   'Sqft': 1249,
#   'Sqm': 116.03},
#  {'Name': 'The Seafront On Meyer',
#   'Price': 4788888,
#   'Address': '55 Meyer Road ',
#   'District': ' D15',
#   'Completion_Year': '2010 ',
#   'Leasehold': ' Freehold',
#   'Bedroom': '4',
#   'Bathroom': 4,
#   'Sqft': 2110,
#   'Sqm': 196.02},
#  {'Name': 'The Linq @ Beauty World',
#   'Price': 999999,
#   'Address': '118 Upper Bukit Timah Road ',
#   'District': ' D21',
#   'Completion_Year': '2023 ',
#   'Leasehold': ' Freehold',
#   'Bedroom': '1',
#   'Bathroom': 1,
#   'Sqft': 431,
#   'Sqm': 40.04},
#  {'Name': 'Parbury Hill Condominium',
# ...
#   'Address': '50 Everton Road ',
#   'District': ' D2',
#   'Completion_Year': '2023 ',
#   'Leasehold': ' Freehold',
#   'Bedroom': '3',
#   'Bathroom': 1,
#   'Sqft': 915,
#   'Sqm': 85.0},
#  {'Name': 'The Crest',
#   'Price': 2176000,
#   'Address': '103 Prince Charles Crescent ',
#   'District': ' D3',
#   'Completion_Year': '2018 ',
#   'Leasehold': ' 99 years',
#   'Bedroom': '3',
#   'Bathroom': 4,
#   'Sqft': 1195,
#   'Sqm': 111.01},
#  {'Name': 'Wallich Residence',
#   'Price': 2097800,
#   'Address': '3 Wallich Street ',
#   'District': ' D2',
#   'Completion_Year': '2022 ',
#   'Leasehold': ' 99 years',
#   'Bedroom': '1',
#   'Bathroom': 1,
#   'Sqft': 646,
#   'Sqm': 60.01},
#  {'Name': 'Residence Twenty-Two',
#   'Price': 843860,
#   'Address': '246 Telok Kurau Road ',
#   'District': ' D15',
#   'Completion_Year': '2021 ',
#   'Leasehold': ' Freehold',
#   'Bedroom': 'Na',
#   'Bathroom': 0,
#   'Sqft': 495,
#   'Sqm': 45.98},
#  {'Name': 'Wilshire Residences',
#   'Price': 1172000,
#   'Address': '30 Farrer Road ',
#   'District': ' D10',
#   'Completion_Year': '2023 ',
#   'Leasehold': ' Freehold',
#   'Bedroom': '1',
#   'Bathroom': 1,
#   'Sqft': 463,
#   'Sqm': 43.01},
#  {'Name': 'The Glyndebourne',
#   'Price': 5680000,
#   'Address': '38 Trevose Crescent ',
#   'District': ' D11',
#   'Completion_Year': '2014 ',
#   'Leasehold': ' Freehold',
#   'Bedroom': '4',
#   'Bathroom': 4,
#   'Sqft': 2756,
#   'Sqm': 256.04},
#  {'Name': '3 Cuscaden',
#   'Price': 5083000,
#   'Address': '3 Cuscaden Walk ',
#   'District': ' D10',
#   'Completion_Year': '2021 ',
#   'Leasehold': ' Freehold',
#   'Bedroom': '3',
#   'Bathroom': 4,
#   'Sqft': 1270,
#   'Sqm': 117.98},
#  {'Name': 'High Park Residences',
#   'Price': 780000,
#   'Address': '57 Fernvale Road ',
#   'District': ' D28',
#   'Completion_Year': '2019 ',
#   'Leasehold': ' 99 years',
#   'Bedroom': '2',
#   'Bathroom': 1,
#   'Sqft': 592,
#   'Sqm': 54.99},
#  {'Name': 'The Crest',
#   'Price': 3222000,
#   'Address': '103 Prince Charles Crescent ',
#   'District': ' D3',
#   'Completion_Year': '2018 ',
#   'Leasehold': ' 99 years',
#   'Bedroom': '4',
#   'Bathroom': 4,
#   'Sqft': 1604,
#   'Sqm': 149.01},
#  {'Name': 'Parc Rosewood',
#   'Price': 500000,
#   'Address': '77 Rosewood Drive ',
#   'District': ' D25',
#   'Completion_Year': '2014 ',
#   'Leasehold': ' 99 years',
#   'Bedroom': '1',
#   'Bathroom': 1,
#   'Sqft': 431,
#   'Sqm': 40.04},
#  {'Name': 'Trilight',
#   'Price': 2292480,
#   'Address': '7 Newton Road ',
#   'District': ' D11',
#   'Completion_Year': '2012 ',
#   'Leasehold': ' Freehold',
#   'Bedroom': '2',
#   'Bathroom': 2,
#   'Sqft': 1194,
#   'Sqm': 110.92},
#  {'Name': 'Flo Residence',
#   'Price': 818000,
#   'Address': '1 Punggol Field Walk ',
#   'District': ' D19',
#   'Completion_Year': '2016 ',
#   'Leasehold': ' 99 years',
#   'Bedroom': '2',
#   'Bathroom': 2,
#   'Sqft': 764,
#   'Sqm': 70.97},
#  {'Name': 'Baywater',
#   'Price': 1298000,
#   'Address': '806 Bedok Reservoir Road ',
#   'District': ' D16',
#   'Completion_Year': '2006 ',
#   'Leasehold': ' 99 years',
#   'Bedroom': '3',
#   'Bathroom': 2,
#   'Sqft': 1281,
#   'Sqm': 119.0},
#  {'Name': 'Daintree Residence',
#   'Price': 1165700,
#   'Address': '11A Toh Tuck Road ',
#   'District': ' D21',
#   'Completion_Year': '2022 ',
#   'Leasehold': ' 99 years',
#   'Bedroom': '2',
#   'Bathroom': 1,
#   'Sqft': 678,
#   'Sqm': 62.98},
#  {'Name': 'Geylang Heritage',
#   'Price': 1300000,
#   'Address': '34 Lorong 34 Geylang ',
#   'District': ' D14',
#   'Completion_Year': '1999 ',
#   'Leasehold': ' Freehold',
#   'Bedroom': '3',
#   'Bathroom': 2,
#   'Sqft': 1227,
#   'Sqm': 113.99},
#  {'Name': 'The Crest',
#   'Price': 3087000,
#   'Address': '101 Prince Charles Crescent ',
#   'District': ' D3',
#   'Completion_Year': '2018 ',
#   'Leasehold': ' 99 years',
#   'Bedroom': '3',
#   'Bathroom': 3,
#   'Sqft': 1625,
#   'Sqm': 150.96},
#  {'Name': 'M5',
#   'Price': 1033000,
#   'Address': '5 Jalan Mutiara ',
#   'District': ' D10',
#   'Completion_Year': '2017 ',
#   'Leasehold': ' Freehold',
#   'Bedroom': '1',
#   'Bathroom': 1,
#   'Sqft': 441,
#   'Sqm': 40.97},
#  {'Name': 'Riversound Residence',
#   'Price': 838000,
#   'Address': '5 Sengkang East Avenue ',
#   'District': ' D19',
#   'Completion_Year': '2015 ',
#   'Leasehold': ' 99 years',
#   'Bedroom': '2',
#   'Bathroom': 2,
#   'Sqft': 754,
#   'Sqm': 70.04},
#  {'Name': 'The Garden Residences',
#   'Price': 1049000,
#   'Address': '7 Serangoon North View ',
#   'District': ' D19',
#   'Completion_Year': '2021 ',
#   'Leasehold': ' 99 years',
#   'Bedroom': '2',
#   'Bathroom': 1,
#   'Sqft': 614,
#   'Sqm': 57.04},
#  {'Name': 'Parbury Hill Condominium',
#   'Price': 1888000,
#   'Address': '38 Parbury Avenue ',
#   'District': ' D16',
#   'Completion_Year': '1998 ',
#   'Leasehold': ' Freehold',
#   'Bedroom': '3',
#   'Bathroom': 3,
#   'Sqft': 1453,
#   'Sqm': 134.98},
#  {'Name': 'Oasis Garden',
#   'Price': 1100000,
#   'Address': '55 Jalan Bunga Rampai ',
#   'District': ' D19',
#   'Completion_Year': '2009 ',
#   'Leasehold': ' Freehold',
#   'Bedroom': '2',
#   'Bathroom': 2,
#   'Sqft': 947,
#   'Sqm': 87.97},
#  {'Name': 'Sant Ritz',
#   'Price': 1680000,
#   'Address': '1 Pheng Geck Avenue ',
#   'District': ' D13',
#   'Completion_Year': '2016 ',
#   'Leasehold': ' 99 years',
#   'Bedroom': '2',
#   'Bathroom': 1,
#   'Sqft': 1227,
#   'Sqm': 113.99},
#  {'Name': 'The Garden Residences',
#   'Price': 752800,
#   'Address': '3 Serangoon North View ',
#   'District': ' D19',
#   'Completion_Year': '2021 ',
#   'Leasehold': ' 99 years',
#   'Bedroom': '1',
#   'Bathroom': 1,
#   'Sqft': 463,
#   'Sqm': 43.01},
#  {'Name': 'Kovan Melody',
#   'Price': 1490000,
#   'Address': '25 Kovan Road ',
#   'District': ' D19',
#   'Completion_Year': '2006 ',
#   'Leasehold': ' 99 years',
#   'Bedroom': '3',
#   'Bathroom': 3,
#   'Sqft': 1227,
#   'Sqm': 113.99},
#  {'Name': 'Rivertrees Residences',
#   'Price': 780000,
#   'Address': '25 Fernvale Close ',
#   'District': ' D28',
#   'Completion_Year': '2018 ',
#   'Leasehold': ' 99 years',
#   'Bedroom': '2',
#   'Bathroom': 1,
#   'Sqft': 581,
#   'Sqm': 53.97},
#  {'Name': 'The Crest',
#   'Price': 2175300,
#   'Address': '107 Prince Charles Crescent ',
#   'District': ' D3',
#   'Completion_Year': '2018 ',
#   'Leasehold': ' 99 years',
#   'Bedroom': 'Na',
#   'Bathroom': 0,
#   'Sqft': 1141,
#   'Sqm': 106.0},
#  {'Name': 'Marina One Residences',
#   'Price': 1778040,
#   'Address': '23 Marina Way ',
#   'District': ' D1',
#   'Completion_Year': '2018 ',
#   'Leasehold': ' 99 years',
#   'Bedroom': '1',
#   'Bathroom': 1,
#   'Sqft': 721,
#   'Sqm': 66.98},
#  {'Name': 'Natura @ Hillview',
#   'Price': 1420000,
#   'Address': '18 Hillview Terrace ',
#   'District': ' D0',
#   'Completion_Year': '2015 ',
#   'Leasehold': ' Freehold',
#   'Bedroom': '3',
#   'Bathroom': 2,
#   'Sqft': 1216,
#   'Sqm': 112.97},
#  {'Name': 'Scotts Square',
#   'Price': 4800000,
#   'Address': '8 Scotts Road ',
#   'District': ' D9',
#   'Completion_Year': '2010 ',
#   'Leasehold': ' Freehold',
#   'Bedroom': '3',
#   'Bathroom': 3,
#   'Sqft': 1227,
#   'Sqm': 113.99},
#  {'Name': 'Dynasty Garden',
#   'Price': 3700000,
#   'Address': '271 Sixth Avenue ',
#   'District': ' D10',
#   'Completion_Year': '1982 ',
#   'Leasehold': ' Freehold',
#   'Bedroom': '3',
#   'Bathroom': 4,
#   'Sqft': 2300,
#   'Sqm': 213.67},
#  {'Name': 'The Garden Residences',
#   'Price': 836000,
#   'Address': '1 Serangoon North View ',
#   'District': ' D19',
#   'Completion_Year': '2021 ',
#   'Leasehold': ' 99 years',
#   'Bedroom': '1',
#   'Bathroom': 1,
#   'Sqft': 517,
#   'Sqm': 48.03},
#  {'Name': 'Estella Gardens',
#   'Price': 1250000,
#   'Address': '29 Flora Road ',
#   'District': ' D17',
#   'Completion_Year': '1999 ',
#   'Leasehold': ' Freehold',
#   'Bedroom': '3',
#   'Bathroom': 3,
#   'Sqft': 1292,
#   'Sqm': 120.03},
#  {'Name': 'Alba',
#   'Price': 27000000,
#   'Address': '8 Cairnhill Rise ',
#   'District': ' D9',
#   'Completion_Year': '2015 ',
#   'Leasehold': ' Freehold',
#   'Bedroom': 'Na',
#   'Bathroom': 0,
#   'Sqft': 6437,
#   'Sqm': 598.01},
#  {'Name': 'The Garden Residences',
#   'Price': 1038600,
#   'Address': '9 Serangoon North View ',
#   'District': ' D19',
#   'Completion_Year': '2021 ',
#   'Leasehold': ' 99 years',
#   'Bedroom': '2',
#   'Bathroom': 2,
#   'Sqft': 689,
#   'Sqm': 64.01},
#  {'Name': 'H2O Residences',
#   'Price': 930000,
#   'Address': '34 Fernvale Link ',
#   'District': ' D28',
#   'Completion_Year': '2015 ',
#   'Leasehold': ' 99 years',
#   'Bedroom': '2',
#   'Bathroom': 2,
#   'Sqft': 850,
#   'Sqm': 78.96},
#  {'Name': 'Kerrisdale',
#   'Price': 1500000,
#   'Address': '36 Sturdee Road ',
#   'District': ' D8',
#   'Completion_Year': '2005 ',
#   'Leasehold': ' 99 years',
#   'Bedroom': '3',
#   'Bathroom': 3,
#   'Sqft': 1259,
#   'Sqm': 116.96},
#  {'Name': 'Sophia Hills',
#   'Price': 1920000,
#   'Address': '11 Mount Sophia ',
#   'District': ' D9',
#   'Completion_Year': '2018 ',
#   'Leasehold': ' 99 years',
#   'Bedroom': '3',
#   'Bathroom': 2,
#   'Sqft': 850,
#   'Sqm': 78.96},
#  {'Name': 'The Garden Residences',
#   'Price': 1192700,
#   'Address': '1 Serangoon North View ',
#   'District': ' D19',
#   'Completion_Year': '2021 ',
#   'Leasehold': ' 99 years',
#   'Bedroom': '3',
#   'Bathroom': 2,
#   'Sqft': 786,
#   'Sqm': 73.02},
#  {'Name': 'Woodhaven',
#   'Price': 800000,
#   'Address': '71 Woodgrove Avenue ',
#   'District': ' D25',
#   'Completion_Year': '2015 ',
#   'Leasehold': ' 99 years',
#   'Bedroom': '2',
#   'Bathroom': 1,
#   'Sqft': 732,
#   'Sqm': 68.0},
#  {'Name': 'Le Quest',
#   'Price': 1140000,
#   'Address': '2 Bukit Batok Street 41 ',
#   'District': ' D23',
#   'Completion_Year': '2020 ',
#   'Leasehold': ' 99 years',
#   'Bedroom': '2',
#   'Bathroom': 1,
#   'Sqft': 614,
#   'Sqm': 57.04},
#  {'Name': 'Fortune Jade',
#   'Price': 1600000,
#   'Address': '501 Dunman Road ',
#   'District': ' D15',
#   'Completion_Year': '2004 ',
#   'Leasehold': ' Freehold',
#   'Bedroom': '3',
#   'Bathroom': 3,
#   'Sqft': 1141,
#   'Sqm': 106.0},
#  {'Name': 'Riversound Residence',
#   'Price': 1238888,
#   'Address': '3 Sengkang East Avenue ',
#   'District': ' D19',
#   'Completion_Year': '2015 ',
#   'Leasehold': ' 99 years',
#   'Bedroom': '4',
#   'Bathroom': 3,
#   'Sqft': 1163,
#   'Sqm': 108.04},
#  {'Name': 'Changi Rise Condominium',
#   'Price': 930000,
#   'Address': '20 Simei Rise ',
#   'District': ' D18',
#   'Completion_Year': '2004 ',
#   'Leasehold': ' 99 years',
#   'Bedroom': '3',
#   'Bathroom': 3,
#   'Sqft': 1259,
#   'Sqm': 116.96},
#  {'Name': 'Skies Miltonia',
#   'Price': 770000,
#   'Address': '3 Miltonia Close ',
#   'District': ' D27',
#   'Completion_Year': '2016 ',
#   'Leasehold': ' 99 years',
#   'Bedroom': '2',
#   'Bathroom': 2,
#   'Sqft': 721,
#   'Sqm': 66.98},
#  {'Name': 'Livia',
#   'Price': 1390000,
#   'Address': '81 Pasir Ris Grove ',
#   'District': ' D18',
#   'Completion_Year': '2011 ',
#   'Leasehold': ' 99 years',
#   'Bedroom': '3',
#   'Bathroom': 3,
#   'Sqft': 1410,
#   'Sqm': 130.99},
#  {'Name': 'Nova 88',
#   'Price': 1380000,
#   'Address': '8 Bhamo Road ',
#   'District': ' D12',
#   'Completion_Year': '2014 ',
#   'Leasehold': ' Freehold',
#   'Bedroom': '2',
#   'Bathroom': 2,
#   'Sqft': 926,
#   'Sqm': 86.02},
#  {'Name': 'The Garden Residences',
#   'Price': 1570800,
#   'Address': '9 Serangoon North View ',
#   'District': ' D19',
#   'Completion_Year': '2021 ',
#   'Leasehold': ' 99 years',
#   'Bedroom': '3',
#   'Bathroom': 3,
#   'Sqft': 904,
#   'Sqm': 83.98},
#  {'Name': 'The Parc Condominium',
#   'Price': 1900000,
#   'Address': '9 West Coast Walk ',
#   'District': ' D5',
#   'Completion_Year': '2010 ',
#   'Leasehold': ' Freehold',
#   'Bedroom': '3',
#   'Bathroom': 3,
#   'Sqft': 1292,
#   'Sqm': 120.03},
#  {'Name': 'Parc Elegance',
#   'Price': 1290000,
#   'Address': '15 Telok Kurau Road ',
#   'District': ' D15',
#   'Completion_Year': '2013 ',
#   'Leasehold': ' Freehold',
#   'Bedroom': '2',
#   'Bathroom': 2,
#   'Sqft': 1152,
#   'Sqm': 107.02},
#  {'Name': 'Symphony Suites',
#   'Price': 920000,
#   'Address': '3 Yishun Close ',
#   'District': ' D27',
#   'Completion_Year': '2019 ',
#   'Leasehold': ' 99 years',
#   'Bedroom': '3',
#   'Bathroom': 2,
#   'Sqft': 797,
#   'Sqm': 74.04},
#  {'Name': 'Gem Residences',
#   'Price': 908000,
#   'Address': '1 Lorong 5 Toa Payoh ',
#   'District': ' D12',
#   'Completion_Year': '2020 ',
#   'Leasehold': ' 99 years',
#   'Bedroom': '1',
#   'Bathroom': 1,
#   'Sqft': 484,
#   'Sqm': 44.96},
#  {'Name': 'A Treasure Trove',
#   'Price': 1199000,
#   'Address': '66 Punggol Walk ',
#   'District': ' D19',
#   'Completion_Year': '2015 ',
#   'Leasehold': ' 99 years',
#   'Bedroom': '3',
#   'Bathroom': 3,
#   'Sqft': 1044,
#   'Sqm': 96.99},
#  {'Name': 'Mi Casa',
#   'Price': 1238000,
#   'Address': '321 Choa Chu Kang Avenue 3 ',
#   'District': ' D23',
#   'Completion_Year': '2012 ',
#   'Leasehold': ' 99 years',
#   'Bedroom': '3',
#   'Bathroom': 3,
#   'Sqft': 1259,
#   'Sqm': 116.96},
#  {'Name': 'The Vision',
#   'Price': 3300000,
#   'Address': '59 West Coast Crescent ',
#   'District': ' D5',
#   'Completion_Year': '2013 ',
#   'Leasehold': ' 99 years',
#   'Bedroom': '4',
#   'Bathroom': 6,
#   'Sqft': 5004,
#   'Sqm': 464.88},
#  {'Name': 'The Garden Residences',
#   'Price': 1726400,
#   'Address': '7 Serangoon North View ',
#   'District': ' D19',
#   'Completion_Year': '2021 ',
#   'Leasehold': ' 99 years',
#   'Bedroom': '4',
#   'Bathroom': 3,
#   'Sqft': 1119,
#   'Sqm': 103.95},
#  {'Name': 'Mi Casa',
#   'Price': 938000,
#   'Address': '317 Choa Chu Kang Avenue 3 ',
#   'District': ' D23',
#   'Completion_Year': '2012 ',
#   'Leasehold': ' 99 years',
#   'Bedroom': '2',
#   'Bathroom': 2,
#   'Sqft': 990,
#   'Sqm': 91.97},
#  {'Name': 'Windermere',
#   'Price': 1400000,
#   'Address': '22 Choa Chu Kang Street 64 ',
#   'District': ' D23',
#   'Completion_Year': '1999 ',
#   'Leasehold': ' 99 years',
#   'Bedroom': 'Na',
#   'Bathroom': 0,
#   'Sqft': 2055,
#   'Sqm': 190.91},
#  {'Name': 'Regent Grove',
#   'Price': 815000,
#   'Address': '50 Choa Chu Kang North 7 ',
#   'District': ' D23',
#   'Completion_Year': '2000 ',
#   'Leasehold': ' 99 years',
#   'Bedroom': 'Na',
#   'Bathroom': 0,
#   'Sqft': 1163,
#   'Sqm': 108.04},
#  {'Name': 'Haig 162',
#   'Price': 620000,
#   'Address': '162 Haig Road ',
#   'District': ' D15',
#   'Completion_Year': '2013 ',
#   'Leasehold': ' Freehold',
#   'Bedroom': '1',
#   'Bathroom': 1,
#   'Sqft': 366,
#   'Sqm': 34.0},
#  {'Name': 'The Centris',
#   'Price': 1130000,
#   'Address': '71 Jurong West Central 3 ',
#   'District': ' D22',
#   'Completion_Year': '2009 ',
#   'Leasehold': ' 99 years',
#   'Bedroom': '2',
#   'Bathroom': 2,
#   'Sqft': 937,
#   'Sqm': 87.05},
#  {'Name': 'Hallmark Residences',
#   'Price': 4900000,
#   'Address': '17 Ewe Boon Road ',
#   'District': ' D10',
#   'Completion_Year': '2015 ',
#   'Leasehold': ' Freehold',
#   'Bedroom': '4',
#   'Bathroom': 4,
#   'Sqft': 1863,
#   'Sqm': 173.07},
#  {'Name': 'Botanique At Bartley',
#   'Price': 1120000,
#   'Address': '227 Upper Paya Lebar Road ',
#   'District': ' D19',
#   'Completion_Year': '2019 ',
#   'Leasehold': ' 99 years',
#   'Bedroom': '2',
#   'Bathroom': 2,
#   'Sqft': 732,
#   'Sqm': 68.0},
#  {'Name': 'Riverbank @ Fernvale',
#   'Price': 768000,
#   'Address': '11 Fernvale Close ',
#   'District': ' D28',
#   'Completion_Year': '2018 ',
#   'Leasehold': ' 99 years',
#   'Bedroom': '2',
#   'Bathroom': 1,
#   'Sqft': 689,
#   'Sqm': 64.01},
#  {'Name': 'The Garden Residences',
#   'Price': 1817100,
#   'Address': '5 Serangoon North View ',
#   'District': ' D19',
#   'Completion_Year': '2021 ',
#   'Leasehold': ' 99 years',
#   'Bedroom': '4',
#   'Bathroom': 4,
#   'Sqft': 1195,
#   'Sqm': 111.01},
#  {'Name': 'JadeScape',
#   'Price': 920816,
#   'Address': '16 Shunfu Road ',
#   'District': ' D20',
#   'Completion_Year': '2023 ',
#   'Leasehold': ' 99 years',
#   'Bedroom': '1',
#   'Bathroom': 1,
#   'Sqft': 527,
#   'Sqm': 48.95},
#  {'Name': 'JadeScape',
#   'Price': 1868776,
#   'Address': '16 Shunfu Road ',
#   'District': ' D20',
#   'Completion_Year': '2023 ',
#   'Leasehold': ' 99 years',
#   'Bedroom': '3',
#   'Bathroom': 3,
#   'Sqft': 1152,
#   'Sqm': 107.02},
#  {'Name': 'Parc Clematis',
#   'Price': 1162000,
#   'Address': '10 Jalan Lempeng ',
#   'District': ' D5',
#   'Completion_Year': '2023 ',
#   'Leasehold': ' 99 years',
#   'Bedroom': '2',
#   'Bathroom': 2,
#   'Sqft': 721,
#   'Sqm': 66.98},
#  {'Name': 'Dairy Farm Residences',
#   'Price': 2008900,
#   'Address': '12 Dairy Farm Lane ',
#   'District': ' D23',
#   'Completion_Year': '2024 ',
#   'Leasehold': ' 99 years',
#   'Bedroom': '4',
#   'Bathroom': 3,
#   'Sqft': 1324,
#   'Sqm': 123.0},
#  {'Name': 'Midtown Bay',
#   'Price': 1431200,
#   'Address': '122 Beach Road ',
#   'District': ' D7',
#   'Completion_Year': '2022 ',
#   'Leasehold': ' 99 years',
#   'Bedroom': '1',
#   'Bathroom': 1,
#   'Sqft': 452,
#   'Sqm': 41.99},
#  ...]

# %%
df = pd.DataFrame(data)

# %%
df.shape
# Out:
# (2800, 10)

# %%
df.to_csv('outputversion.csv')
